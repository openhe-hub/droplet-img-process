# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
from io import BytesIO
from loguru import logger
import json

from config.carbon_mixed import *

input_folder_path = r'E:\record\sideview_mixed_dataset'
output_label_path = './output/label'
output_feature_path = './output/feature'
output_data_path = './output/data'

# %%
dataset_dirs = []


def list_directories(path):
    directories = [d for d in os.listdir(path)
                   if os.path.isdir(os.path.join(path, d))]
    return directories


dataset_dirs = list_directories(input_folder_path)
len(dataset_dirs)
# Out:
# 90

# %%
analyze_conditions('POD_0.5_0.25_0.25_30C_100kPa_1', 10)
# Out:
# {'p_ratio': 50.0,
#  'o_ratio': 25.0,
#  'd_ratio': 25.0,
#  'temperature': 30.0,
#  'pressure': 100.0,
#  'frame_id': 10}

# %%
def count_jpg_files(folder_path):
    jpg_files = [f for f in os.listdir(folder_path)
                 if f.lower().endswith('.jpg')]
    return len(jpg_files)

# %%
def exec_one_folder(input_path, use_index_or_filename=True):
	def list_img_files():
		files = os.listdir(input_path)
		jpg_files = sorted([file for file in files if file.endswith('jpg') and file[-5] != ')'])
		return jpg_files
	img_files = list_img_files()
	logger.success(f'{input_path} listed, {len(img_files)} imgs found.')

	base_idx = count_jpg_files(output_feature_path)
	start_idx = 0
	cnt = 0
	for idx, path in enumerate(img_files):
		frame_id = analyze_frame_id(path)
		if idx == 0 : start_idx = frame_id
		output_img = cv2.imread(f'{input_path}/{img_files[idx]}')
	
		data = analyze_conditions(input_path, frame_id - start_idx)
		values = list(data.values())
		pts = [[i, i] for i in range(len(values))] 
		matrix = np.zeros((len(values), len(values)))
		for value, pt in zip(values, pts):
			matrix[pt[0], pt[1]] = value
		plt.imshow(matrix, cmap='viridis', interpolation='nearest')
		plt.axis('off')
		
		buf = BytesIO()
		plt.savefig(buf, format='jpg', bbox_inches='tight', pad_inches=0, dpi=300)
		plt.close()
		buf.seek(0)
		input_img = np.frombuffer(buf.getvalue(), dtype=np.int8)
		input_img = cv2.imdecode(input_img, cv2.IMREAD_COLOR)
		height, width = output_img.shape[:2]
		input_img = cv2.resize(input_img, (width, height))

		if use_index_or_filename:
			real_idx = base_idx + cnt
			cv2.imwrite(f'{output_feature_path}/{real_idx}.jpg', input_img)
			cv2.imwrite(f'{output_label_path}/{real_idx}.jpg', output_img)
			with open(f'{output_data_path}/{real_idx}.json', 'w', encoding='utf-8') as fp:
				json.dump(data, fp, ensure_ascii=False, indent=4)
		else:
			cv2.imwrite(f'{output_feature_path}/{img_files[idx]}.jpg', input_img)
			cv2.imwrite(f'{output_label_path}/{img_files[idx]}.jpg', output_img)
			with open(f'{output_data_path}/{img_files[idx]}.json', 'w', encoding='utf-8') as fp:
				json.dump(data, fp, ensure_ascii=False, indent=4)
		
		logger.success(f'Finish handling {input_path} / {idx}.')
		cnt += 1

# %%
# exec_one_folder(input_path=input_folder_path, use_index_or_filename=False)

# %%
for dataset_dir in dataset_dirs:
	input_path = os.path.join(input_folder_path, dataset_dir)
	exec_one_folder(input_path=input_path)
	logger.success(f"Finish handling {input_path}")
# Out:
# 2025-06-29 14:21:16.233 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_100kPa_ (1) listed, 21 imgs found.
# 2025-06-29 14:21:16.381 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_100kPa_ (1) / 0.
# 2025-06-29 14:21:16.485 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_100kPa_ (1) / 1.
# 2025-06-29 14:21:16.581 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_100kPa_ (1) / 2.
# 2025-06-29 14:21:16.688 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_100kPa_ (1) / 3.
# 2025-06-29 14:21:16.788 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_100kPa_ (1) / 4.
# 2025-06-29 14:21:16.883 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_100kPa_ (1) / 5.
# 2025-06-29 14:21:16.979 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_100kPa_ (1) / 6.
# 2025-06-29 14:21:17.078 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_100kPa_ (1) / 7.
# 2025-06-29 14:21:17.175 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_100kPa_ (1) / 8.
# 2025-06-29 14:21:17.270 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_100kPa_ (1) / 9.
# 2025-06-29 14:21:17.373 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_100kPa_ (1) / 10.
# 2025-06-29 14:21:17.465 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_100kPa_ (1) / 11.
# 2025-06-29 14:21:17.560 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_100kPa_ (1) / 12.
# 2025-06-29 14:21:17.657 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_100kPa_ (1) / 13.
# 2025-06-29 14:21:17.757 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_100kPa_ (1) / 14.
# 2025-06-29 14:21:17.853 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_100kPa_ (1) / 15.
# 2025-06-29 14:21:17.947 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_100kPa_ (1) / 16.
# 2025-06-29 14:21:18.049 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_100kPa_ (1) / 17.
# 2025-06-29 14:21:18.153 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_100kPa_ (1) / 18.
# 2025-06-29 14:21:18.248 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_100kPa_ (1) / 19.
# 2025-06-29 14:21:18.345 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_100kPa_ (1) / 20.
# 2025-06-29 14:21:18.345 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_100kPa_ (1)
# 2025-06-29 14:21:18.346 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_20kPa_ (1) listed, 21 imgs found.
# 2025-06-29 14:21:18.440 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_20kPa_ (1) / 0.
# 2025-06-29 14:21:18.536 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_20kPa_ (1) / 1.
# 2025-06-29 14:21:18.633 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_20kPa_ (1) / 2.
# 2025-06-29 14:21:18.730 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_20kPa_ (1) / 3.
# 2025-06-29 14:21:18.838 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_20kPa_ (1) / 4.
# 2025-06-29 14:21:18.935 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_20kPa_ (1) / 5.
# 2025-06-29 14:21:19.037 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_20kPa_ (1) / 6.
# 2025-06-29 14:21:19.138 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_20kPa_ (1) / 7.
# 2025-06-29 14:21:19.230 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_20kPa_ (1) / 8.
# 2025-06-29 14:21:19.325 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_20kPa_ (1) / 9.
# 2025-06-29 14:21:19.417 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_20kPa_ (1) / 10.
# 2025-06-29 14:21:19.509 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_20kPa_ (1) / 11.
# 2025-06-29 14:21:19.606 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_20kPa_ (1) / 12.
# 2025-06-29 14:21:19.702 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_20kPa_ (1) / 13.
# 2025-06-29 14:21:19.803 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_20kPa_ (1) / 14.
# 2025-06-29 14:21:19.896 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_20kPa_ (1) / 15.
# 2025-06-29 14:21:20.021 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_20kPa_ (1) / 16.
# 2025-06-29 14:21:20.120 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_20kPa_ (1) / 17.
# 2025-06-29 14:21:20.225 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_20kPa_ (1) / 18.
# 2025-06-29 14:21:20.322 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_20kPa_ (1) / 19.
# 2025-06-29 14:21:20.420 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_20kPa_ (1) / 20.
# 2025-06-29 14:21:20.421 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_20kPa_ (1)
# 2025-06-29 14:21:20.422 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_50kPa_ (1) listed, 21 imgs found.
# 2025-06-29 14:21:20.516 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_50kPa_ (1) / 0.
# 2025-06-29 14:21:20.611 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_50kPa_ (1) / 1.
# 2025-06-29 14:21:20.705 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_50kPa_ (1) / 2.
# 2025-06-29 14:21:20.806 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_50kPa_ (1) / 3.
# 2025-06-29 14:21:20.908 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_50kPa_ (1) / 4.
# 2025-06-29 14:21:21.007 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_50kPa_ (1) / 5.
# 2025-06-29 14:21:21.101 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_50kPa_ (1) / 6.
# 2025-06-29 14:21:21.197 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_50kPa_ (1) / 7.
# 2025-06-29 14:21:21.297 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_50kPa_ (1) / 8.
# 2025-06-29 14:21:21.392 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_50kPa_ (1) / 9.
# 2025-06-29 14:21:21.497 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_50kPa_ (1) / 10.
# 2025-06-29 14:21:21.590 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_50kPa_ (1) / 11.
# 2025-06-29 14:21:21.691 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_50kPa_ (1) / 12.
# 2025-06-29 14:21:21.792 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_50kPa_ (1) / 13.
# 2025-06-29 14:21:21.885 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_50kPa_ (1) / 14.
# 2025-06-29 14:21:21.978 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_50kPa_ (1) / 15.
# 2025-06-29 14:21:22.079 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_50kPa_ (1) / 16.
# 2025-06-29 14:21:22.181 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_50kPa_ (1) / 17.
# 2025-06-29 14:21:22.275 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_50kPa_ (1) / 18.
# 2025-06-29 14:21:22.399 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_50kPa_ (1) / 19.
# 2025-06-29 14:21:22.498 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_50kPa_ (1) / 20.
# 2025-06-29 14:21:22.498 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_30C_50kPa_ (1)
# 2025-06-29 14:21:22.499 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_100kPa_ (1) listed, 21 imgs found.
# 2025-06-29 14:21:22.589 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_100kPa_ (1) / 0.
# 2025-06-29 14:21:22.679 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_100kPa_ (1) / 1.
# 2025-06-29 14:21:22.775 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_100kPa_ (1) / 2.
# 2025-06-29 14:21:22.871 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_100kPa_ (1) / 3.
# 2025-06-29 14:21:22.975 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_100kPa_ (1) / 4.
# 2025-06-29 14:21:23.072 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_100kPa_ (1) / 5.
# 2025-06-29 14:21:23.168 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_100kPa_ (1) / 6.
# 2025-06-29 14:21:23.264 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_100kPa_ (1) / 7.
# 2025-06-29 14:21:23.357 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_100kPa_ (1) / 8.
# 2025-06-29 14:21:23.447 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_100kPa_ (1) / 9.
# 2025-06-29 14:21:23.541 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_100kPa_ (1) / 10.
# 2025-06-29 14:21:23.637 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_100kPa_ (1) / 11.
# 2025-06-29 14:21:23.770 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_100kPa_ (1) / 12.
# 2025-06-29 14:21:23.886 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_100kPa_ (1) / 13.
# 2025-06-29 14:21:23.988 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_100kPa_ (1) / 14.
# 2025-06-29 14:21:24.087 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_100kPa_ (1) / 15.
# 2025-06-29 14:21:24.187 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_100kPa_ (1) / 16.
# 2025-06-29 14:21:24.289 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_100kPa_ (1) / 17.
# 2025-06-29 14:21:24.390 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_100kPa_ (1) / 18.
# 2025-06-29 14:21:24.493 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_100kPa_ (1) / 19.
# 2025-06-29 14:21:24.591 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_100kPa_ (1) / 20.
# 2025-06-29 14:21:24.591 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_100kPa_ (1)
# 2025-06-29 14:21:24.592 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_20kPa_ (1) listed, 21 imgs found.
# 2025-06-29 14:21:24.689 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_20kPa_ (1) / 0.
# 2025-06-29 14:21:24.788 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_20kPa_ (1) / 1.
# 2025-06-29 14:21:24.887 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_20kPa_ (1) / 2.
# 2025-06-29 14:21:24.983 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_20kPa_ (1) / 3.
# 2025-06-29 14:21:25.088 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_20kPa_ (1) / 4.
# 2025-06-29 14:21:25.192 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_20kPa_ (1) / 5.
# 2025-06-29 14:21:25.292 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_20kPa_ (1) / 6.
# 2025-06-29 14:21:25.393 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_20kPa_ (1) / 7.
# 2025-06-29 14:21:25.505 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_20kPa_ (1) / 8.
# 2025-06-29 14:21:25.601 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_20kPa_ (1) / 9.
# 2025-06-29 14:21:25.703 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_20kPa_ (1) / 10.
# 2025-06-29 14:21:25.802 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_20kPa_ (1) / 11.
# 2025-06-29 14:21:25.915 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_20kPa_ (1) / 12.
# 2025-06-29 14:21:26.017 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_20kPa_ (1) / 13.
# 2025-06-29 14:21:26.117 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_20kPa_ (1) / 14.
# 2025-06-29 14:21:26.217 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_20kPa_ (1) / 15.
# 2025-06-29 14:21:26.323 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_20kPa_ (1) / 16.
# 2025-06-29 14:21:26.428 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_20kPa_ (1) / 17.
# 2025-06-29 14:21:26.539 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_20kPa_ (1) / 18.
# 2025-06-29 14:21:26.643 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_20kPa_ (1) / 19.
# 2025-06-29 14:21:26.748 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_20kPa_ (1) / 20.
# 2025-06-29 14:21:26.749 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_20kPa_ (1)
# 2025-06-29 14:21:26.750 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_50kPa_ (1) listed, 21 imgs found.
# 2025-06-29 14:21:26.846 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_50kPa_ (1) / 0.
# 2025-06-29 14:21:26.946 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_50kPa_ (1) / 1.
# 2025-06-29 14:21:27.045 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_50kPa_ (1) / 2.
# 2025-06-29 14:21:27.143 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_50kPa_ (1) / 3.
# 2025-06-29 14:21:27.241 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_50kPa_ (1) / 4.
# 2025-06-29 14:21:27.358 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_50kPa_ (1) / 5.
# 2025-06-29 14:21:27.468 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_50kPa_ (1) / 6.
# 2025-06-29 14:21:27.575 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_50kPa_ (1) / 7.
# 2025-06-29 14:21:27.719 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_50kPa_ (1) / 8.
# 2025-06-29 14:21:27.825 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_50kPa_ (1) / 9.
# 2025-06-29 14:21:27.923 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_50kPa_ (1) / 10.
# 2025-06-29 14:21:28.022 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_50kPa_ (1) / 11.
# 2025-06-29 14:21:28.120 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_50kPa_ (1) / 12.
# 2025-06-29 14:21:28.224 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_50kPa_ (1) / 13.
# 2025-06-29 14:21:28.324 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_50kPa_ (1) / 14.
# 2025-06-29 14:21:28.432 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_50kPa_ (1) / 15.
# 2025-06-29 14:21:28.537 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_50kPa_ (1) / 16.
# 2025-06-29 14:21:28.633 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_50kPa_ (1) / 17.
# 2025-06-29 14:21:28.733 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_50kPa_ (1) / 18.
# 2025-06-29 14:21:28.829 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_50kPa_ (1) / 19.
# 2025-06-29 14:21:28.924 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_50kPa_ (1) / 20.
# 2025-06-29 14:21:28.925 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_40C_50kPa_ (1)
# 2025-06-29 14:21:28.926 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_100kPa_ (1) listed, 21 imgs found.
# 2025-06-29 14:21:29.027 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_100kPa_ (1) / 0.
# 2025-06-29 14:21:29.138 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_100kPa_ (1) / 1.
# 2025-06-29 14:21:29.236 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_100kPa_ (1) / 2.
# 2025-06-29 14:21:29.329 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_100kPa_ (1) / 3.
# 2025-06-29 14:21:29.436 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_100kPa_ (1) / 4.
# 2025-06-29 14:21:29.542 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_100kPa_ (1) / 5.
# 2025-06-29 14:21:29.639 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_100kPa_ (1) / 6.
# 2025-06-29 14:21:29.736 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_100kPa_ (1) / 7.
# 2025-06-29 14:21:29.839 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_100kPa_ (1) / 8.
# 2025-06-29 14:21:29.932 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_100kPa_ (1) / 9.
# 2025-06-29 14:21:30.027 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_100kPa_ (1) / 10.
# 2025-06-29 14:21:30.136 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_100kPa_ (1) / 11.
# 2025-06-29 14:21:30.252 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_100kPa_ (1) / 12.
# 2025-06-29 14:21:30.346 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_100kPa_ (1) / 13.
# 2025-06-29 14:21:30.440 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_100kPa_ (1) / 14.
# 2025-06-29 14:21:30.536 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_100kPa_ (1) / 15.
# 2025-06-29 14:21:30.647 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_100kPa_ (1) / 16.
# 2025-06-29 14:21:30.745 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_100kPa_ (1) / 17.
# 2025-06-29 14:21:30.843 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_100kPa_ (1) / 18.
# 2025-06-29 14:21:30.949 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_100kPa_ (1) / 19.
# 2025-06-29 14:21:31.042 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_100kPa_ (1) / 20.
# 2025-06-29 14:21:31.043 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_100kPa_ (1)
# 2025-06-29 14:21:31.043 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_20kPa_ (1) listed, 21 imgs found.
# 2025-06-29 14:21:31.139 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_20kPa_ (1) / 0.
# 2025-06-29 14:21:31.233 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_20kPa_ (1) / 1.
# 2025-06-29 14:21:31.337 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_20kPa_ (1) / 2.
# 2025-06-29 14:21:31.439 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_20kPa_ (1) / 3.
# 2025-06-29 14:21:31.532 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_20kPa_ (1) / 4.
# 2025-06-29 14:21:31.627 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_20kPa_ (1) / 5.
# 2025-06-29 14:21:31.722 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_20kPa_ (1) / 6.
# 2025-06-29 14:21:31.817 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_20kPa_ (1) / 7.
# 2025-06-29 14:21:31.920 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_20kPa_ (1) / 8.
# 2025-06-29 14:21:32.019 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_20kPa_ (1) / 9.
# 2025-06-29 14:21:32.114 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_20kPa_ (1) / 10.
# 2025-06-29 14:21:32.268 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_20kPa_ (1) / 11.
# 2025-06-29 14:21:32.361 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_20kPa_ (1) / 12.
# 2025-06-29 14:21:32.457 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_20kPa_ (1) / 13.
# 2025-06-29 14:21:32.566 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_20kPa_ (1) / 14.
# 2025-06-29 14:21:32.658 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_20kPa_ (1) / 15.
# 2025-06-29 14:21:32.766 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_20kPa_ (1) / 16.
# 2025-06-29 14:21:32.863 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_20kPa_ (1) / 17.
# 2025-06-29 14:21:32.961 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_20kPa_ (1) / 18.
# 2025-06-29 14:21:33.062 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_20kPa_ (1) / 19.
# 2025-06-29 14:21:33.160 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_20kPa_ (1) / 20.
# 2025-06-29 14:21:33.161 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_20kPa_ (1)
# 2025-06-29 14:21:33.162 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_50kPa_ (1) listed, 21 imgs found.
# 2025-06-29 14:21:33.261 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_50kPa_ (1) / 0.
# 2025-06-29 14:21:33.361 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_50kPa_ (1) / 1.
# 2025-06-29 14:21:33.452 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_50kPa_ (1) / 2.
# 2025-06-29 14:21:33.550 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_50kPa_ (1) / 3.
# 2025-06-29 14:21:33.647 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_50kPa_ (1) / 4.
# 2025-06-29 14:21:33.755 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_50kPa_ (1) / 5.
# 2025-06-29 14:21:33.856 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_50kPa_ (1) / 6.
# 2025-06-29 14:21:33.962 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_50kPa_ (1) / 7.
# 2025-06-29 14:21:34.061 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_50kPa_ (1) / 8.
# 2025-06-29 14:21:34.158 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_50kPa_ (1) / 9.
# 2025-06-29 14:21:34.252 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_50kPa_ (1) / 10.
# 2025-06-29 14:21:34.354 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_50kPa_ (1) / 11.
# 2025-06-29 14:21:34.446 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_50kPa_ (1) / 12.
# 2025-06-29 14:21:34.542 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_50kPa_ (1) / 13.
# 2025-06-29 14:21:34.637 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_50kPa_ (1) / 14.
# 2025-06-29 14:21:34.730 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_50kPa_ (1) / 15.
# 2025-06-29 14:21:34.826 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_50kPa_ (1) / 16.
# 2025-06-29 14:21:34.927 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_50kPa_ (1) / 17.
# 2025-06-29 14:21:35.023 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_50kPa_ (1) / 18.
# 2025-06-29 14:21:35.133 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_50kPa_ (1) / 19.
# 2025-06-29 14:21:35.229 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_50kPa_ (1) / 20.
# 2025-06-29 14:21:35.230 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_50C_50kPa_ (1)
# 2025-06-29 14:21:35.231 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_100kPa_ (1) listed, 21 imgs found.
# 2025-06-29 14:21:35.325 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_100kPa_ (1) / 0.
# 2025-06-29 14:21:35.420 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_100kPa_ (1) / 1.
# 2025-06-29 14:21:35.513 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_100kPa_ (1) / 2.
# 2025-06-29 14:21:35.609 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_100kPa_ (1) / 3.
# 2025-06-29 14:21:35.703 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_100kPa_ (1) / 4.
# 2025-06-29 14:21:35.810 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_100kPa_ (1) / 5.
# 2025-06-29 14:21:35.909 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_100kPa_ (1) / 6.
# 2025-06-29 14:21:36.003 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_100kPa_ (1) / 7.
# 2025-06-29 14:21:36.100 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_100kPa_ (1) / 8.
# 2025-06-29 14:21:36.198 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_100kPa_ (1) / 9.
# 2025-06-29 14:21:36.292 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_100kPa_ (1) / 10.
# 2025-06-29 14:21:36.407 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_100kPa_ (1) / 11.
# 2025-06-29 14:21:36.499 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_100kPa_ (1) / 12.
# 2025-06-29 14:21:36.592 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_100kPa_ (1) / 13.
# 2025-06-29 14:21:36.683 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_100kPa_ (1) / 14.
# 2025-06-29 14:21:36.780 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_100kPa_ (1) / 15.
# 2025-06-29 14:21:36.875 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_100kPa_ (1) / 16.
# 2025-06-29 14:21:36.977 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_100kPa_ (1) / 17.
# 2025-06-29 14:21:37.072 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_100kPa_ (1) / 18.
# 2025-06-29 14:21:37.163 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_100kPa_ (1) / 19.
# 2025-06-29 14:21:37.261 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_100kPa_ (1) / 20.
# 2025-06-29 14:21:37.262 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_100kPa_ (1)
# 2025-06-29 14:21:37.263 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_20kPa_ (1) listed, 21 imgs found.
# 2025-06-29 14:21:37.367 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_20kPa_ (1) / 0.
# 2025-06-29 14:21:37.473 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_20kPa_ (1) / 1.
# 2025-06-29 14:21:37.574 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_20kPa_ (1) / 2.
# 2025-06-29 14:21:37.756 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_20kPa_ (1) / 3.
# 2025-06-29 14:21:37.869 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_20kPa_ (1) / 4.
# 2025-06-29 14:21:37.977 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_20kPa_ (1) / 5.
# 2025-06-29 14:21:38.081 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_20kPa_ (1) / 6.
# 2025-06-29 14:21:38.181 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_20kPa_ (1) / 7.
# 2025-06-29 14:21:38.285 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_20kPa_ (1) / 8.
# 2025-06-29 14:21:38.389 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_20kPa_ (1) / 9.
# 2025-06-29 14:21:38.496 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_20kPa_ (1) / 10.
# 2025-06-29 14:21:38.600 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_20kPa_ (1) / 11.
# 2025-06-29 14:21:38.719 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_20kPa_ (1) / 12.
# 2025-06-29 14:21:38.827 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_20kPa_ (1) / 13.
# 2025-06-29 14:21:38.948 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_20kPa_ (1) / 14.
# 2025-06-29 14:21:39.050 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_20kPa_ (1) / 15.
# 2025-06-29 14:21:39.166 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_20kPa_ (1) / 16.
# 2025-06-29 14:21:39.286 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_20kPa_ (1) / 17.
# 2025-06-29 14:21:39.405 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_20kPa_ (1) / 18.
# 2025-06-29 14:21:39.520 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_20kPa_ (1) / 19.
# 2025-06-29 14:21:39.630 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_20kPa_ (1) / 20.
# 2025-06-29 14:21:39.632 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_20kPa_ (1)
# 2025-06-29 14:21:39.632 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_50kPa_ (1) listed, 21 imgs found.
# 2025-06-29 14:21:39.742 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_50kPa_ (1) / 0.
# 2025-06-29 14:21:39.848 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_50kPa_ (1) / 1.
# 2025-06-29 14:21:39.949 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_50kPa_ (1) / 2.
# 2025-06-29 14:21:40.057 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_50kPa_ (1) / 3.
# 2025-06-29 14:21:40.171 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_50kPa_ (1) / 4.
# 2025-06-29 14:21:40.281 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_50kPa_ (1) / 5.
# 2025-06-29 14:21:40.387 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_50kPa_ (1) / 6.
# 2025-06-29 14:21:40.490 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_50kPa_ (1) / 7.
# 2025-06-29 14:21:40.598 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_50kPa_ (1) / 8.
# 2025-06-29 14:21:40.707 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_50kPa_ (1) / 9.
# 2025-06-29 14:21:40.818 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_50kPa_ (1) / 10.
# 2025-06-29 14:21:40.935 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_50kPa_ (1) / 11.
# 2025-06-29 14:21:41.039 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_50kPa_ (1) / 12.
# 2025-06-29 14:21:41.147 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_50kPa_ (1) / 13.
# 2025-06-29 14:21:41.256 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_50kPa_ (1) / 14.
# 2025-06-29 14:21:41.365 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_50kPa_ (1) / 15.
# 2025-06-29 14:21:41.475 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_50kPa_ (1) / 16.
# 2025-06-29 14:21:41.597 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_50kPa_ (1) / 17.
# 2025-06-29 14:21:41.704 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_50kPa_ (1) / 18.
# 2025-06-29 14:21:41.816 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_50kPa_ (1) / 19.
# 2025-06-29 14:21:41.918 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_50kPa_ (1) / 20.
# 2025-06-29 14:21:41.919 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_60C_50kPa_ (1)
# 2025-06-29 14:21:41.920 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_100kPa_ (1) listed, 21 imgs found.
# 2025-06-29 14:21:42.019 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_100kPa_ (1) / 0.
# 2025-06-29 14:21:42.129 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_100kPa_ (1) / 1.
# 2025-06-29 14:21:42.233 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_100kPa_ (1) / 2.
# 2025-06-29 14:21:42.339 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_100kPa_ (1) / 3.
# 2025-06-29 14:21:42.446 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_100kPa_ (1) / 4.
# 2025-06-29 14:21:42.565 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_100kPa_ (1) / 5.
# 2025-06-29 14:21:42.686 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_100kPa_ (1) / 6.
# 2025-06-29 14:21:42.790 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_100kPa_ (1) / 7.
# 2025-06-29 14:21:42.898 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_100kPa_ (1) / 8.
# 2025-06-29 14:21:43.019 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_100kPa_ (1) / 9.
# 2025-06-29 14:21:43.127 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_100kPa_ (1) / 10.
# 2025-06-29 14:21:43.235 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_100kPa_ (1) / 11.
# 2025-06-29 14:21:43.336 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_100kPa_ (1) / 12.
# 2025-06-29 14:21:43.441 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_100kPa_ (1) / 13.
# 2025-06-29 14:21:43.554 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_100kPa_ (1) / 14.
# 2025-06-29 14:21:43.657 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_100kPa_ (1) / 15.
# 2025-06-29 14:21:43.762 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_100kPa_ (1) / 16.
# 2025-06-29 14:21:43.867 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_100kPa_ (1) / 17.
# 2025-06-29 14:21:43.973 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_100kPa_ (1) / 18.
# 2025-06-29 14:21:44.083 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_100kPa_ (1) / 19.
# 2025-06-29 14:21:44.192 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_100kPa_ (1) / 20.
# 2025-06-29 14:21:44.193 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_100kPa_ (1)
# 2025-06-29 14:21:44.194 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_20kPa_ (1) listed, 21 imgs found.
# 2025-06-29 14:21:44.299 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_20kPa_ (1) / 0.
# 2025-06-29 14:21:44.401 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_20kPa_ (1) / 1.
# 2025-06-29 14:21:44.503 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_20kPa_ (1) / 2.
# 2025-06-29 14:21:44.611 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_20kPa_ (1) / 3.
# 2025-06-29 14:21:44.720 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_20kPa_ (1) / 4.
# 2025-06-29 14:21:44.832 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_20kPa_ (1) / 5.
# 2025-06-29 14:21:44.935 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.125_0.5_0.375_70C_20kPa_ (1) / 6.
# ...
# 2025-06-29 14:24:41.700 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_50kPa_1 / 10.
# 2025-06-29 14:24:41.811 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_50kPa_1 / 11.
# 2025-06-29 14:24:41.937 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_50kPa_1 / 12.
# 2025-06-29 14:24:42.060 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_50kPa_1 / 13.
# 2025-06-29 14:24:42.177 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_50kPa_1 / 14.
# 2025-06-29 14:24:42.292 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_50kPa_1 / 15.
# 2025-06-29 14:24:42.408 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_50kPa_1 / 16.
# 2025-06-29 14:24:42.526 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_50kPa_1 / 17.
# 2025-06-29 14:24:42.645 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_50kPa_1 / 18.
# 2025-06-29 14:24:42.762 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_50kPa_1 / 19.
# 2025-06-29 14:24:42.880 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_50kPa_1 / 20.
# 2025-06-29 14:24:42.880 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_50kPa_1
# 2025-06-29 14:24:42.881 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_60kPa_1 listed, 21 imgs found.
# 2025-06-29 14:24:42.999 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_60kPa_1 / 0.
# 2025-06-29 14:24:43.115 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_60kPa_1 / 1.
# 2025-06-29 14:24:43.231 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_60kPa_1 / 2.
# 2025-06-29 14:24:43.350 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_60kPa_1 / 3.
# 2025-06-29 14:24:43.468 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_60kPa_1 / 4.
# 2025-06-29 14:24:43.585 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_60kPa_1 / 5.
# 2025-06-29 14:24:43.713 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_60kPa_1 / 6.
# 2025-06-29 14:24:43.831 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_60kPa_1 / 7.
# 2025-06-29 14:24:43.948 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_60kPa_1 / 8.
# 2025-06-29 14:24:44.068 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_60kPa_1 / 9.
# 2025-06-29 14:24:44.185 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_60kPa_1 / 10.
# 2025-06-29 14:24:44.302 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_60kPa_1 / 11.
# 2025-06-29 14:24:44.419 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_60kPa_1 / 12.
# 2025-06-29 14:24:44.544 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_60kPa_1 / 13.
# 2025-06-29 14:24:44.665 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_60kPa_1 / 14.
# 2025-06-29 14:24:44.779 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_60kPa_1 / 15.
# 2025-06-29 14:24:44.896 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_60kPa_1 / 16.
# 2025-06-29 14:24:45.013 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_60kPa_1 / 17.
# 2025-06-29 14:24:45.129 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_60kPa_1 / 18.
# 2025-06-29 14:24:45.244 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_60kPa_1 / 19.
# 2025-06-29 14:24:45.362 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_60kPa_1 / 20.
# 2025-06-29 14:24:45.362 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_60kPa_1
# 2025-06-29 14:24:45.364 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_70kPa_1 listed, 21 imgs found.
# 2025-06-29 14:24:45.483 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_70kPa_1 / 0.
# 2025-06-29 14:24:45.600 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_70kPa_1 / 1.
# 2025-06-29 14:24:45.717 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_70kPa_1 / 2.
# 2025-06-29 14:24:45.839 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_70kPa_1 / 3.
# 2025-06-29 14:24:45.961 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_70kPa_1 / 4.
# 2025-06-29 14:24:46.084 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_70kPa_1 / 5.
# 2025-06-29 14:24:46.207 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_70kPa_1 / 6.
# 2025-06-29 14:24:46.329 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_70kPa_1 / 7.
# 2025-06-29 14:24:46.448 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_70kPa_1 / 8.
# 2025-06-29 14:24:46.567 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_70kPa_1 / 9.
# 2025-06-29 14:24:46.692 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_70kPa_1 / 10.
# 2025-06-29 14:24:46.809 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_70kPa_1 / 11.
# 2025-06-29 14:24:46.926 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_70kPa_1 / 12.
# 2025-06-29 14:24:47.048 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_70kPa_1 / 13.
# 2025-06-29 14:24:47.169 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_70kPa_1 / 14.
# 2025-06-29 14:24:47.298 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_70kPa_1 / 15.
# 2025-06-29 14:24:47.421 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_70kPa_1 / 16.
# 2025-06-29 14:24:47.546 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_70kPa_1 / 17.
# 2025-06-29 14:24:47.669 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_70kPa_1 / 18.
# 2025-06-29 14:24:47.791 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_70kPa_1 / 19.
# 2025-06-29 14:24:47.916 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_70kPa_1 / 20.
# 2025-06-29 14:24:47.917 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_70kPa_1
# 2025-06-29 14:24:47.918 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_80kPa_1 listed, 21 imgs found.
# 2025-06-29 14:24:48.037 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_80kPa_1 / 0.
# 2025-06-29 14:24:48.160 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_80kPa_1 / 1.
# 2025-06-29 14:24:48.287 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_80kPa_1 / 2.
# 2025-06-29 14:24:48.407 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_80kPa_1 / 3.
# 2025-06-29 14:24:48.528 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_80kPa_1 / 4.
# 2025-06-29 14:24:48.649 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_80kPa_1 / 5.
# 2025-06-29 14:24:48.772 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_80kPa_1 / 6.
# 2025-06-29 14:24:48.894 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_80kPa_1 / 7.
# 2025-06-29 14:24:49.014 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_80kPa_1 / 8.
# 2025-06-29 14:24:49.133 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_80kPa_1 / 9.
# 2025-06-29 14:24:49.254 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_80kPa_1 / 10.
# 2025-06-29 14:24:49.376 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_80kPa_1 / 11.
# 2025-06-29 14:24:49.490 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_80kPa_1 / 12.
# 2025-06-29 14:24:49.610 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_80kPa_1 / 13.
# 2025-06-29 14:24:49.725 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_80kPa_1 / 14.
# 2025-06-29 14:24:49.843 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_80kPa_1 / 15.
# 2025-06-29 14:24:49.964 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_80kPa_1 / 16.
# 2025-06-29 14:24:50.086 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_80kPa_1 / 17.
# 2025-06-29 14:24:50.206 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_80kPa_1 / 18.
# 2025-06-29 14:24:50.345 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_80kPa_1 / 19.
# 2025-06-29 14:24:50.465 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_80kPa_1 / 20.
# 2025-06-29 14:24:50.467 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_80kPa_1
# 2025-06-29 14:24:50.467 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_90kPa_1 listed, 21 imgs found.
# 2025-06-29 14:24:50.591 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_90kPa_1 / 0.
# 2025-06-29 14:24:50.712 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_90kPa_1 / 1.
# 2025-06-29 14:24:50.835 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_90kPa_1 / 2.
# 2025-06-29 14:24:50.956 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_90kPa_1 / 3.
# 2025-06-29 14:24:51.080 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_90kPa_1 / 4.
# 2025-06-29 14:24:51.205 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_90kPa_1 / 5.
# 2025-06-29 14:24:51.333 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_90kPa_1 / 6.
# 2025-06-29 14:24:51.457 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_90kPa_1 / 7.
# 2025-06-29 14:24:51.576 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_90kPa_1 / 8.
# 2025-06-29 14:24:51.700 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_90kPa_1 / 9.
# 2025-06-29 14:24:51.820 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_90kPa_1 / 10.
# 2025-06-29 14:24:51.941 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_90kPa_1 / 11.
# 2025-06-29 14:24:52.063 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_90kPa_1 / 12.
# 2025-06-29 14:24:52.187 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_90kPa_1 / 13.
# 2025-06-29 14:24:52.311 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_90kPa_1 / 14.
# 2025-06-29 14:24:52.433 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_90kPa_1 / 15.
# 2025-06-29 14:24:52.558 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_90kPa_1 / 16.
# 2025-06-29 14:24:52.683 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_90kPa_1 / 17.
# 2025-06-29 14:24:52.807 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_90kPa_1 / 18.
# 2025-06-29 14:24:52.928 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_90kPa_1 / 19.
# 2025-06-29 14:24:53.047 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_90kPa_1 / 20.
# 2025-06-29 14:24:53.048 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\sideview_mixed_dataset\POD_0.5_0.375_0.125_80C_90kPa_1

# %%
# split train/valid/test
import os
import random
import shutil

# folder paths
source_folder = './output/feature'
train_folder = './output/feature/train'
val_folder = './output/feature/valid'
test_folder = './output/feature/test'

os.makedirs(train_folder, exist_ok=True)
os.makedirs(val_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)

images = [f for f in os.listdir(source_folder) if os.path.isfile(os.path.join(source_folder, f))]

random.shuffle(images)

# train/valid/test ratios
train_ratio = 0.9
val_ratio = 0.05

train_size = int(train_ratio * len(images))
val_size = int(val_ratio * len(images))
test_size = len(images) - train_size - val_size

train_set = images[:train_size]
val_set = images[train_size:train_size + val_size]
test_set = images[train_size + val_size:]

def move_files(file_list, destination_folder):
    for file_name in file_list:
        src_path = os.path.join(source_folder, file_name)
        dst_path = os.path.join(destination_folder, file_name)
        shutil.move(src_path, dst_path)

move_files(train_set, train_folder)
move_files(val_set, val_folder)
move_files(test_set, test_folder)

print(f"train set: {len(train_set)} imgs")
print(f"valid set: {len(val_set)} imgs")
print(f"test set: {len(test_set)} imgs")
# Out:
# train set: 1683 imgs
# valid set: 93 imgs
# test set: 94 imgs

# %%
# split train/valid/test
import os
import random
import shutil

source_folder = './output/label'
train_folder = './output/label/train'
val_folder = './output/label/valid'
test_folder = './output/label/test'

os.makedirs(train_folder, exist_ok=True)
os.makedirs(val_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)

images = [f for f in os.listdir(source_folder) if os.path.isfile(os.path.join(source_folder, f))]

def move_files(file_list, destination_folder):
    for file_name in file_list:
        src_path = os.path.join(source_folder, file_name)
        dst_path = os.path.join(destination_folder, file_name)
        shutil.move(src_path, dst_path)

move_files(train_set, train_folder)
move_files(val_set, val_folder)
move_files(test_set, test_folder)

print(f"train set: {len(train_set)} imgs")
print(f"valid set: {len(val_set)} imgs")
print(f"test set: {len(test_set)} imgs")
# Out:
# train set: 1683 imgs
# valid set: 93 imgs
# test set: 94 imgs
