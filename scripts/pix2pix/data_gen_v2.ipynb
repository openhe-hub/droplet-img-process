# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
from io import BytesIO
from loguru import logger
import json

input_folder_path = r'E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001'
output_label_path = './output/label'
output_feature_path = './output/feature'
output_data_path = './output/data'

# %%
dataset_dirs = []


def list_directories(path):
    directories = [d for d in os.listdir(path)
                   if os.path.isdir(os.path.join(path, d))]
    return directories


dataset_dirs = list_directories(input_folder_path)
len(dataset_dirs)
# Out:
# 0

# %%
surface_type_keys = ['S1', 'S2', 'S3', 'S4', 'S5', 'S6']
surface_type_vals = [(i+1) / (len(surface_type_keys)+1) for i in range(len(surface_type_keys))]
surface_type_dict = dict(zip(surface_type_keys, surface_type_vals))

fall_point_type_keys = ['OG1', 'OG', 'OG2', 'OR1', 'OR', 'OR2', 'C', 'R', 'G']

fall_point_type_vals = [(i+1) / (len(fall_point_type_keys)+1) for i in range(len(fall_point_type_keys))]
fall_point_type_dict = dict(zip(fall_point_type_keys, fall_point_type_vals))

liquid_type_keys = ['W']
liquid_type_vals = [(i+1) / (len(fall_point_type_keys)+1)
                    for i in range(len(fall_point_type_keys))]
liquid_type_dict = dict(zip(liquid_type_keys, liquid_type_vals))

surface_type_dict, fall_point_type_dict, liquid_type_dict
# Out:
# ({'S1': 0.14285714285714285,
#   'S2': 0.2857142857142857,
#   'S3': 0.42857142857142855,
#   'S4': 0.5714285714285714,
#   'S5': 0.7142857142857143,
#   'S6': 0.8571428571428571},
#  {'OG1': 0.1,
#   'OG': 0.2,
#   'OG2': 0.3,
#   'OR1': 0.4,
#   'OR': 0.5,
#   'OR2': 0.6,
#   'C': 0.7,
#   'R': 0.8,
#   'G': 0.9},
#  {'W': 0.1})

# %%
frame_id_range = [0, 40]
height_range = [10, 40]
diameter_range = [18, 25]
sm1_range = [3, 7]

# %%
def get_smooth1_data(surface_type):
    sm1 =  6.2

    if surface_type == 'S1': sm1 = 3.914
    elif surface_type == 'S2': sm1 = 7.5
    
    return (sm1 - sm1_range[0]) / (sm1_range[1] - sm1_range[0])

def get_delta_elevation(surface_type):
    delta_elevation = 0

    if surface_type == 'S4': delta_elevation = 0.33
    elif surface_type == 'S5': delta_elevation = 0.656
    elif surface_type == 'S6': delta_elevation = 1

    return delta_elevation

# %%
def analyze_conditions(path, frame_id):
    label = path.split('\\')[-1]
    seg = label.split('-')
    data = {}
    if len(seg) == 6:
        data['surface_type'] = surface_type_dict[seg[0]]
        data['liquid_type'] = liquid_type_dict[seg[1]]
        data['diameter'] = (int(seg[2][:2]) - diameter_range[0]) / (diameter_range[1] - diameter_range[0])
        data['height']  = (int(seg[3][:2]) - height_range[0]) / (height_range[1] - height_range[0])
        data['fall_point_type'] = fall_point_type_dict[seg[4]]
        data['frame_id'] = (frame_id - frame_id_range[0]) / (frame_id_range[1] - frame_id_range[0])
        data['sm1'] = get_smooth1_data(seg[0])
        data['sm2'] = 0.429
        data['delta_elevation'] = get_delta_elevation(seg[0])

    return data

# %%
def count_jpg_files(folder_path):
    jpg_files = [f for f in os.listdir(folder_path)
                 if f.lower().endswith('.jpg')]
    return len(jpg_files)

# %%
def exec_one_folder(input_path, use_index_or_filename=True):
	def list_img_files():
		files = os.listdir(input_path)
		jpg_files = sorted([file for file in files if file.endswith('jpg') and file.startswith('raw')])
		return jpg_files
	img_files = list_img_files()
	logger.success(f'{input_path} listed, {len(img_files)} imgs found.')

	base_idx = count_jpg_files(output_feature_path)
	start_idx = 0
	cnt = 0
	for idx, path in enumerate(img_files):
		frame_id = int(path[-10:-4])
		if idx <= 1 : 
			start_idx = frame_id
			continue # skip the first several images
		output_img = cv2.imread(f'{input_path}/{img_files[idx]}')
		prev_output_img1 = cv2.imread(f'{input_path}/{img_files[idx-2]}')
		prev_output_img2 = cv2.imread(f'{input_path}/{img_files[idx-1]}')
	
		data = analyze_conditions(input_path, frame_id - start_idx)
		values = list(data.values())
		pts = [[i, i] for i in range(len(values))] 
		matrix = np.zeros((len(values), len(values)))
		for value, pt in zip(values, pts):
			matrix[pt[0], pt[1]] = value
		plt.imshow(matrix, cmap='viridis', interpolation='nearest')
		plt.axis('off')
		
		buf = BytesIO()
		plt.savefig(buf, format='jpg', bbox_inches='tight', pad_inches=0, dpi=300)
		plt.close()
		buf.seek(0)
		input_img = np.frombuffer(buf.getvalue(), dtype=np.int8)
		input_img = cv2.imdecode(input_img, cv2.IMREAD_COLOR)

		# prev_output_img1 = cv2.resize(prev_output_img1, (input_img.shape[1], int(input_img.shape[0]/2)))
		# prev_output_img2 = cv2.resize(prev_output_img2, (input_img.shape[1], int(input_img.shape[0]/2)))
		# prev_output_img = cv2.vconcat([prev_output_img1, prev_output_img2])
		# input_img = cv2.hconcat([input_img, prev_output_img])
		height, width = output_img.shape[:2]
		input_img = cv2.resize(input_img, (width, height))

		if use_index_or_filename:
			real_idx = base_idx + cnt
			cv2.imwrite(f'{output_feature_path}/{real_idx}.jpg', input_img)
			cv2.imwrite(f'{output_label_path}/{real_idx}.jpg', output_img)
			with open(f'{output_data_path}/{real_idx}.json', 'w', encoding='utf-8') as fp:
				json.dump(data, fp, ensure_ascii=False, indent=4)
		else:
			cv2.imwrite(f'{output_feature_path}/{img_files[idx]}.jpg', input_img)
			cv2.imwrite(f'{output_label_path}/{img_files[idx]}.jpg', output_img)
			with open(f'{output_data_path}/{img_files[idx]}.json', 'w', encoding='utf-8') as fp:
				json.dump(data, fp, ensure_ascii=False, indent=4)
		
		logger.success(f'Finish handling {input_path} / {idx}.')
		cnt += 1

# %%
exec_one_folder(input_path=input_folder_path, use_index_or_filename=False)
# Out:
# 2025-05-14 12:56:31.043 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 listed, 43 imgs found.
# 2025-05-14 12:56:31.577 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 2.
# 2025-05-14 12:56:31.751 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 3.
# 2025-05-14 12:56:31.899 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 4.
# 2025-05-14 12:56:32.076 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 5.
# 2025-05-14 12:56:32.228 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 6.
# 2025-05-14 12:56:32.375 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 7.
# 2025-05-14 12:56:32.520 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 8.
# 2025-05-14 12:56:32.675 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 9.
# 2025-05-14 12:56:32.838 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 10.
# 2025-05-14 12:56:33.001 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 11.
# 2025-05-14 12:56:33.193 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 12.
# 2025-05-14 12:56:33.356 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 13.
# 2025-05-14 12:56:33.528 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 14.
# 2025-05-14 12:56:33.686 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 15.
# 2025-05-14 12:56:33.863 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 16.
# 2025-05-14 12:56:34.025 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 17.
# 2025-05-14 12:56:34.195 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 18.
# 2025-05-14 12:56:34.365 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 19.
# 2025-05-14 12:56:34.544 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 20.
# 2025-05-14 12:56:34.688 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 21.
# 2025-05-14 12:56:34.850 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 22.
# 2025-05-14 12:56:35.019 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 23.
# 2025-05-14 12:56:35.206 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 24.
# 2025-05-14 12:56:35.372 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 25.
# 2025-05-14 12:56:35.531 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 26.
# 2025-05-14 12:56:35.687 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 27.
# 2025-05-14 12:56:35.852 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 28.
# 2025-05-14 12:56:36.016 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 29.
# 2025-05-14 12:56:36.191 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 30.
# 2025-05-14 12:56:36.349 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 31.
# 2025-05-14 12:56:36.504 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 32.
# 2025-05-14 12:56:36.665 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 33.
# 2025-05-14 12:56:36.829 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 34.
# 2025-05-14 12:56:36.985 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 35.
# 2025-05-14 12:56:37.143 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 36.
# 2025-05-14 12:56:37.299 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 37.
# 2025-05-14 12:56:37.459 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 38.
# 2025-05-14 12:56:37.620 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 39.
# 2025-05-14 12:56:37.798 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 40.
# 2025-05-14 12:56:37.955 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 41.
# 2025-05-14 12:56:38.099 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 42.

# %%
for dataset_dir in dataset_dirs:
	input_path = os.path.join(input_folder_path, dataset_dir)
	exec_one_folder(input_path=input_path)
	logger.success(f"Finish handling {input_path}")
# Out:
# 2025-05-11 19:47:57.146 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 listed, 17 imgs found.
# 2025-05-11 19:47:57.245 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 2.
# 2025-05-11 19:47:57.343 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 3.
# 2025-05-11 19:47:57.444 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 4.
# 2025-05-11 19:47:57.543 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 5.
# 2025-05-11 19:47:57.646 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 6.
# 2025-05-11 19:47:57.754 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 7.
# 2025-05-11 19:47:57.859 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 8.
# 2025-05-11 19:47:57.968 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 9.
# 2025-05-11 19:47:58.065 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 10.
# 2025-05-11 19:47:58.164 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 11.
# 2025-05-11 19:47:58.263 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 12.
# 2025-05-11 19:47:58.364 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 13.
# 2025-05-11 19:47:58.463 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 14.
# 2025-05-11 19:47:58.561 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 15.
# 2025-05-11 19:47:58.660 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 16.
# 2025-05-11 19:47:58.661 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001
# 2025-05-11 19:47:58.662 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 listed, 22 imgs found.
# 2025-05-11 19:47:58.760 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 2.
# 2025-05-11 19:47:58.860 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 3.
# 2025-05-11 19:47:58.959 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 4.
# 2025-05-11 19:47:59.055 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 5.
# 2025-05-11 19:47:59.154 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 6.
# 2025-05-11 19:47:59.255 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 7.
# 2025-05-11 19:47:59.354 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 8.
# 2025-05-11 19:47:59.454 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 9.
# 2025-05-11 19:47:59.551 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 10.
# 2025-05-11 19:47:59.651 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 11.
# 2025-05-11 19:47:59.751 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 12.
# 2025-05-11 19:47:59.851 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 13.
# 2025-05-11 19:47:59.951 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 14.
# 2025-05-11 19:48:00.050 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 15.
# 2025-05-11 19:48:00.147 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 16.
# 2025-05-11 19:48:00.258 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 17.
# 2025-05-11 19:48:00.357 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 18.
# 2025-05-11 19:48:00.456 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 19.
# 2025-05-11 19:48:00.553 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 20.
# 2025-05-11 19:48:00.652 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 21.
# 2025-05-11 19:48:00.653 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001
# 2025-05-11 19:48:00.654 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 listed, 24 imgs found.
# 2025-05-11 19:48:00.752 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 2.
# 2025-05-11 19:48:00.852 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 3.
# 2025-05-11 19:48:00.950 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 4.
# 2025-05-11 19:48:01.049 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 5.
# 2025-05-11 19:48:01.152 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 6.
# 2025-05-11 19:48:01.250 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 7.
# 2025-05-11 19:48:01.354 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 8.
# 2025-05-11 19:48:01.452 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 9.
# 2025-05-11 19:48:01.550 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 10.
# 2025-05-11 19:48:01.648 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 11.
# 2025-05-11 19:48:01.744 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 12.
# 2025-05-11 19:48:01.844 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 13.
# 2025-05-11 19:48:01.941 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 14.
# 2025-05-11 19:48:02.039 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 15.
# 2025-05-11 19:48:02.134 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 16.
# 2025-05-11 19:48:02.232 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 17.
# 2025-05-11 19:48:02.330 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 18.
# 2025-05-11 19:48:02.425 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 19.
# 2025-05-11 19:48:02.524 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 20.
# 2025-05-11 19:48:02.623 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 21.
# 2025-05-11 19:48:02.724 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 22.
# 2025-05-11 19:48:02.820 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 23.
# 2025-05-11 19:48:02.821 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001
# 2025-05-11 19:48:02.822 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 listed, 24 imgs found.
# 2025-05-11 19:48:02.920 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 2.
# 2025-05-11 19:48:03.017 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 3.
# 2025-05-11 19:48:03.118 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 4.
# 2025-05-11 19:48:03.214 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 5.
# 2025-05-11 19:48:03.314 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 6.
# 2025-05-11 19:48:03.417 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 7.
# 2025-05-11 19:48:03.514 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 8.
# 2025-05-11 19:48:03.613 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 9.
# 2025-05-11 19:48:03.710 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 10.
# 2025-05-11 19:48:03.809 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 11.
# 2025-05-11 19:48:03.905 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 12.
# 2025-05-11 19:48:04.003 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 13.
# 2025-05-11 19:48:04.098 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 14.
# 2025-05-11 19:48:04.196 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 15.
# 2025-05-11 19:48:04.305 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 16.
# 2025-05-11 19:48:04.405 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 17.
# 2025-05-11 19:48:04.503 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 18.
# 2025-05-11 19:48:04.602 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 19.
# 2025-05-11 19:48:04.699 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 20.
# 2025-05-11 19:48:04.797 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 21.
# 2025-05-11 19:48:04.900 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 22.
# 2025-05-11 19:48:05.005 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 23.
# 2025-05-11 19:48:05.007 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001
# 2025-05-11 19:48:05.008 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 listed, 21 imgs found.
# 2025-05-11 19:48:05.106 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 2.
# 2025-05-11 19:48:05.209 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 3.
# 2025-05-11 19:48:05.313 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 4.
# 2025-05-11 19:48:05.414 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 5.
# 2025-05-11 19:48:05.514 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 6.
# 2025-05-11 19:48:05.612 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 7.
# 2025-05-11 19:48:05.714 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 8.
# 2025-05-11 19:48:05.811 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 9.
# 2025-05-11 19:48:05.910 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 10.
# 2025-05-11 19:48:06.010 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 11.
# 2025-05-11 19:48:06.108 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 12.
# 2025-05-11 19:48:06.206 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 13.
# 2025-05-11 19:48:06.305 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 14.
# 2025-05-11 19:48:06.403 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 15.
# 2025-05-11 19:48:06.503 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 16.
# 2025-05-11 19:48:06.610 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 17.
# 2025-05-11 19:48:06.711 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 18.
# 2025-05-11 19:48:06.813 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 19.
# 2025-05-11 19:48:06.912 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 20.
# 2025-05-11 19:48:06.913 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001
# 2025-05-11 19:48:06.914 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 listed, 28 imgs found.
# 2025-05-11 19:48:07.015 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 2.
# 2025-05-11 19:48:07.137 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 3.
# 2025-05-11 19:48:07.249 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 4.
# 2025-05-11 19:48:07.360 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 5.
# 2025-05-11 19:48:07.461 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 6.
# 2025-05-11 19:48:07.563 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 7.
# 2025-05-11 19:48:07.666 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 8.
# 2025-05-11 19:48:07.768 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 9.
# 2025-05-11 19:48:07.873 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 10.
# 2025-05-11 19:48:07.981 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 11.
# 2025-05-11 19:48:08.080 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 12.
# 2025-05-11 19:48:08.178 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 13.
# 2025-05-11 19:48:08.275 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 14.
# 2025-05-11 19:48:08.373 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 15.
# 2025-05-11 19:48:08.470 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 16.
# 2025-05-11 19:48:08.568 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 17.
# 2025-05-11 19:48:08.670 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 18.
# 2025-05-11 19:48:08.773 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 19.
# 2025-05-11 19:48:08.873 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 20.
# 2025-05-11 19:48:08.971 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 21.
# 2025-05-11 19:48:09.493 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 22.
# 2025-05-11 19:48:09.605 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 23.
# 2025-05-11 19:48:09.709 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 24.
# 2025-05-11 19:48:09.806 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 25.
# 2025-05-11 19:48:09.903 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 26.
# 2025-05-11 19:48:10.005 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 27.
# 2025-05-11 19:48:10.006 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001
# 2025-05-11 19:48:10.007 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 listed, 35 imgs found.
# 2025-05-11 19:48:10.113 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 2.
# 2025-05-11 19:48:10.213 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 3.
# 2025-05-11 19:48:10.311 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 4.
# 2025-05-11 19:48:10.413 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 5.
# 2025-05-11 19:48:10.514 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 6.
# 2025-05-11 19:48:10.620 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 7.
# 2025-05-11 19:48:10.725 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 8.
# 2025-05-11 19:48:10.830 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 9.
# 2025-05-11 19:48:10.935 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 10.
# 2025-05-11 19:48:11.032 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 11.
# 2025-05-11 19:48:11.129 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 12.
# 2025-05-11 19:48:11.235 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 13.
# 2025-05-11 19:48:11.352 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 14.
# 2025-05-11 19:48:11.457 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 15.
# 2025-05-11 19:48:11.562 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 16.
# 2025-05-11 19:48:11.674 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 17.
# 2025-05-11 19:48:11.773 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 18.
# 2025-05-11 19:48:11.874 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 19.
# 2025-05-11 19:48:11.975 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 20.
# 2025-05-11 19:48:12.071 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 21.
# 2025-05-11 19:48:12.516 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 22.
# 2025-05-11 19:48:13.240 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 23.
# 2025-05-11 19:48:13.894 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 24.
# 2025-05-11 19:48:14.569 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 25.
# 2025-05-11 19:48:15.252 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 26.
# 2025-05-11 19:48:15.910 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 27.
# 2025-05-11 19:48:16.620 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 28.
# 2025-05-11 19:48:17.233 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 29.
# 2025-05-11 19:48:17.885 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 30.
# 2025-05-11 19:48:18.593 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 31.
# 2025-05-11 19:48:19.250 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 32.
# 2025-05-11 19:48:19.891 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 33.
# 2025-05-11 19:48:20.530 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 34.
# 2025-05-11 19:48:20.534 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001
# 2025-05-11 19:48:20.538 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 listed, 21 imgs found.
# 2025-05-11 19:48:21.398 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 2.
# 2025-05-11 19:48:22.084 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 3.
# 2025-05-11 19:48:22.896 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 4.
# 2025-05-11 19:48:23.584 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 5.
# 2025-05-11 19:48:24.253 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 6.
# 2025-05-11 19:48:24.940 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 7.
# 2025-05-11 19:48:25.679 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 8.
# 2025-05-11 19:48:26.565 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 9.
# 2025-05-11 19:48:27.317 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 10.
# 2025-05-11 19:48:27.969 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 11.
# 2025-05-11 19:48:28.630 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 12.
# 2025-05-11 19:48:29.325 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 13.
# 2025-05-11 19:48:30.050 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 14.
# 2025-05-11 19:48:31.113 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 15.
# 2025-05-11 19:48:31.826 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 16.
# 2025-05-11 19:48:32.470 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 17.
# 2025-05-11 19:48:33.142 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 18.
# 2025-05-11 19:48:33.940 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 19.
# 2025-05-11 19:48:34.633 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 20.
# 2025-05-11 19:48:34.638 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001
# 2025-05-11 19:48:34.645 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 listed, 21 imgs found.
# 2025-05-11 19:48:35.321 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 2.
# 2025-05-11 19:48:36.130 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 3.
# 2025-05-11 19:48:36.776 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 4.
# 2025-05-11 19:48:37.427 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 5.
# 2025-05-11 19:48:38.082 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 6.
# 2025-05-11 19:48:38.742 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 7.
# 2025-05-11 19:48:39.480 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 8.
# 2025-05-11 19:48:40.161 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 9.
# 2025-05-11 19:48:40.783 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 10.
# 2025-05-11 19:48:41.518 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 11.
# 2025-05-11 19:48:42.299 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 12.
# 2025-05-11 19:48:42.981 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 13.
# 2025-05-11 19:48:43.673 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 14.
# 2025-05-11 19:48:44.319 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 15.
# 2025-05-11 19:48:45.016 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 16.
# 2025-05-11 19:48:45.705 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 17.
# 2025-05-11 19:48:46.339 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 18.
# 2025-05-11 19:48:47.043 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 19.
# 2025-05-11 19:48:47.700 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 20.
# 2025-05-11 19:48:47.705 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001
# 2025-05-11 19:48:47.709 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-2_C001H001S0001 listed, 18 imgs found.
# 2025-05-11 19:48:48.474 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-2_C001H001S0001 / 2.
# 2025-05-11 19:48:49.212 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-2_C001H001S0001 / 3.
# 2025-05-11 19:48:49.881 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-2_C001H001S0001 / 4.
# 2025-05-11 19:48:50.587 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-2_C001H001S0001 / 5.
# 2025-05-11 19:48:51.288 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-2_C001H001S0001 / 6.
# 2025-05-11 19:48:51.945 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-2_C001H001S0001 / 7.
# 2025-05-11 19:48:52.636 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-2_C001H001S0001 / 8.
# 2025-05-11 19:48:53.315 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-2_C001H001S0001 / 9.
# 2025-05-11 19:48:54.153 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-2_C001H001S0001 / 10.
# 2025-05-11 19:48:54.841 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-2_C001H001S0001 / 11.
# 2025-05-11 19:48:55.535 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-2_C001H001S0001 / 12.
# 2025-05-11 19:48:56.221 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-2_C001H001S0001 / 13.
# 2025-05-11 19:48:56.914 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-2_C001H001S0001 / 14.
# 2025-05-11 19:48:57.625 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-2_C001H001S0001 / 15.
# 2025-05-11 19:48:58.423 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-2_C001H001S0001 / 16.
# 2025-05-11 19:48:59.065 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-2_C001H001S0001 / 17.
# 2025-05-11 19:48:59.069 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-2_C001H001S0001
# 2025-05-11 19:48:59.073 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S3-W-18G-30cm-C-1_C001H001S0001 listed, 21 imgs found.
# 2025-05-11 19:48:59.934 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S3-W-18G-30cm-C-1_C001H001S0001 / 2.
# 2025-05-11 19:49:00.794 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S3-W-18G-30cm-C-1_C001H001S0001 / 3.
# 2025-05-11 19:49:01.456 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S3-W-18G-30cm-C-1_C001H001S0001 / 4.
# 2025-05-11 19:49:02.097 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S3-W-18G-30cm-C-1_C001H001S0001 / 5.
# 2025-05-11 19:49:02.758 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S3-W-18G-30cm-C-1_C001H001S0001 / 6.
# 2025-05-11 19:49:03.448 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S3-W-18G-30cm-C-1_C001H001S0001 / 7.
# ...
# 2025-05-11 19:50:16.725 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-1_C001H001S0001 / 6.
# 2025-05-11 19:50:16.822 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-1_C001H001S0001 / 7.
# 2025-05-11 19:50:16.916 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-1_C001H001S0001 / 8.
# 2025-05-11 19:50:17.015 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-1_C001H001S0001 / 9.
# 2025-05-11 19:50:17.119 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-1_C001H001S0001 / 10.
# 2025-05-11 19:50:17.214 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-1_C001H001S0001 / 11.
# 2025-05-11 19:50:17.311 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-1_C001H001S0001 / 12.
# 2025-05-11 19:50:17.415 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-1_C001H001S0001 / 13.
# 2025-05-11 19:50:17.510 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-1_C001H001S0001 / 14.
# 2025-05-11 19:50:17.606 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-1_C001H001S0001 / 15.
# 2025-05-11 19:50:17.703 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-1_C001H001S0001 / 16.
# 2025-05-11 19:50:17.804 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-1_C001H001S0001 / 17.
# 2025-05-11 19:50:17.905 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-1_C001H001S0001 / 18.
# 2025-05-11 19:50:18.006 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-1_C001H001S0001 / 19.
# 2025-05-11 19:50:18.101 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-1_C001H001S0001 / 20.
# 2025-05-11 19:50:18.102 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-1_C001H001S0001
# 2025-05-11 19:50:18.103 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 listed, 21 imgs found.
# 2025-05-11 19:50:18.199 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 2.
# 2025-05-11 19:50:18.294 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 3.
# 2025-05-11 19:50:18.392 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 4.
# 2025-05-11 19:50:18.487 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 5.
# 2025-05-11 19:50:18.585 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 6.
# 2025-05-11 19:50:18.683 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 7.
# 2025-05-11 19:50:18.780 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 8.
# 2025-05-11 19:50:18.876 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 9.
# 2025-05-11 19:50:18.975 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 10.
# 2025-05-11 19:50:19.071 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 11.
# 2025-05-11 19:50:19.168 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 12.
# 2025-05-11 19:50:19.273 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 13.
# 2025-05-11 19:50:19.369 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 14.
# 2025-05-11 19:50:19.465 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 15.
# 2025-05-11 19:50:19.564 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 16.
# 2025-05-11 19:50:19.661 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 17.
# 2025-05-11 19:50:19.763 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 18.
# 2025-05-11 19:50:19.859 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 19.
# 2025-05-11 19:50:19.954 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 20.
# 2025-05-11 19:50:19.955 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001
# 2025-05-11 19:50:19.956 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 listed, 21 imgs found.
# 2025-05-11 19:50:20.062 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 2.
# 2025-05-11 19:50:20.165 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 3.
# 2025-05-11 19:50:20.259 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 4.
# 2025-05-11 19:50:20.359 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 5.
# 2025-05-11 19:50:20.454 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 6.
# 2025-05-11 19:50:20.553 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 7.
# 2025-05-11 19:50:20.649 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 8.
# 2025-05-11 19:50:20.747 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 9.
# 2025-05-11 19:50:20.841 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 10.
# 2025-05-11 19:50:20.939 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 11.
# 2025-05-11 19:50:21.034 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 12.
# 2025-05-11 19:50:21.134 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 13.
# 2025-05-11 19:50:21.229 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 14.
# 2025-05-11 19:50:21.324 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 15.
# 2025-05-11 19:50:21.432 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 16.
# 2025-05-11 19:50:21.526 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 17.
# 2025-05-11 19:50:21.623 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 18.
# 2025-05-11 19:50:21.723 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 19.
# 2025-05-11 19:50:21.820 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 20.
# 2025-05-11 19:50:21.821 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001
# 2025-05-11 19:50:21.822 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 listed, 21 imgs found.
# 2025-05-11 19:50:21.923 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 2.
# 2025-05-11 19:50:22.023 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 3.
# 2025-05-11 19:50:22.122 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 4.
# 2025-05-11 19:50:22.223 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 5.
# 2025-05-11 19:50:22.325 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 6.
# 2025-05-11 19:50:22.425 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 7.
# 2025-05-11 19:50:22.523 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 8.
# 2025-05-11 19:50:22.620 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 9.
# 2025-05-11 19:50:22.721 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 10.
# 2025-05-11 19:50:22.819 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 11.
# 2025-05-11 19:50:22.915 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 12.
# 2025-05-11 19:50:23.014 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 13.
# 2025-05-11 19:50:23.114 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 14.
# 2025-05-11 19:50:23.210 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 15.
# 2025-05-11 19:50:23.307 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 16.
# 2025-05-11 19:50:23.407 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 17.
# 2025-05-11 19:50:23.508 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 18.
# 2025-05-11 19:50:23.610 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 19.
# 2025-05-11 19:50:23.708 | SUCCESS  | __main__:exec_one_folder:56 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 20.
# 2025-05-11 19:50:23.710 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001

# %%
# split train/valid/test
import os
import random
import shutil

# 定义源文件夹路径和目标文件夹路径
source_folder = './output/feature'
train_folder = './output/feature/train'
val_folder = './output/feature/valid'
test_folder = './output/feature/test'

# 创建目标文件夹（如果不存在）
os.makedirs(train_folder, exist_ok=True)
os.makedirs(val_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)

images = [f for f in os.listdir(source_folder) if os.path.isfile(os.path.join(source_folder, f))]

random.shuffle(images)

# 定义训练集，验证集，测试集比例
train_ratio = 0.0
val_ratio = 0.0

# 80% train + 10% valid + 10% test
train_size = int(train_ratio * len(images))
val_size = int(val_ratio * len(images))
test_size = len(images) - train_size - val_size

train_set = images[:train_size]
val_set = images[train_size:train_size + val_size]
test_set = images[train_size + val_size:]

def move_files(file_list, destination_folder):
    for file_name in file_list:
        src_path = os.path.join(source_folder, file_name)
        dst_path = os.path.join(destination_folder, file_name)
        shutil.move(src_path, dst_path)

move_files(train_set, train_folder)
move_files(val_set, val_folder)
move_files(test_set, test_folder)

print(f"train set: {len(train_set)} imgs")
print(f"valid set: {len(val_set)} imgs")
print(f"test set: {len(test_set)} imgs")
# Out:
# train set: 0 imgs
# valid set: 0 imgs
# test set: 41 imgs

# %%
# split train/valid/test
import os
import random
import shutil

# 定义源文件夹路径和目标文件夹路径
source_folder = './output/label'
train_folder = './output/label/train'
val_folder = './output/label/valid'
test_folder = './output/label/test'

# 创建目标文件夹（如果不存在）
os.makedirs(train_folder, exist_ok=True)
os.makedirs(val_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)

images = [f for f in os.listdir(source_folder) if os.path.isfile(os.path.join(source_folder, f))]

def move_files(file_list, destination_folder):
    for file_name in file_list:
        src_path = os.path.join(source_folder, file_name)
        dst_path = os.path.join(destination_folder, file_name)
        shutil.move(src_path, dst_path)

move_files(train_set, train_folder)
move_files(val_set, val_folder)
move_files(test_set, test_folder)

print(f"train set: {len(train_set)} imgs")
print(f"valid set: {len(val_set)} imgs")
print(f"test set: {len(test_set)} imgs")
# Out:
# train set: 0 imgs
# valid set: 0 imgs
# test set: 41 imgs
