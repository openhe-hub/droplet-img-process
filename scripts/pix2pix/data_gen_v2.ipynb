# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
from io import BytesIO
from loguru import logger
import json

input_folder_path = r'E:\record\sideview_pure_dataset'
output_label_path = './output/label'
output_feature_path = './output/feature'
output_data_path = './output/data'

# %%
dataset_dirs = []


def list_directories(path):
    directories = [d for d in os.listdir(path)
                   if os.path.isdir(os.path.join(path, d))]
    return directories


dataset_dirs = list_directories(input_folder_path)
len(dataset_dirs)
# Out:
# 0

# %%
surface_type_keys = ['S1', 'S2', 'S3', 'S4', 'S5', 'S6']
surface_type_vals = [(i+1) / (len(surface_type_keys)+1) for i in range(len(surface_type_keys))]
surface_type_dict = dict(zip(surface_type_keys, surface_type_vals))

fall_point_type_keys = ['OG1', 'OG', 'OG2', 'OR1', 'OR', 'OR2', 'C', 'R', 'G']

fall_point_type_vals = [(i+1) / (len(fall_point_type_keys)+1) for i in range(len(fall_point_type_keys))]
fall_point_type_dict = dict(zip(fall_point_type_keys, fall_point_type_vals))

liquid_type_keys = ['W']
liquid_type_vals = [(i+1) / (len(fall_point_type_keys)+1)
                    for i in range(len(fall_point_type_keys))]
liquid_type_dict = dict(zip(liquid_type_keys, liquid_type_vals))

surface_type_dict, fall_point_type_dict, liquid_type_dict
# Out:
# ({'S1': 0.14285714285714285,
#   'S2': 0.2857142857142857,
#   'S3': 0.42857142857142855,
#   'S4': 0.5714285714285714,
#   'S5': 0.7142857142857143,
#   'S6': 0.8571428571428571},
#  {'OG1': 0.1,
#   'OG': 0.2,
#   'OG2': 0.3,
#   'OR1': 0.4,
#   'OR': 0.5,
#   'OR2': 0.6,
#   'C': 0.7,
#   'R': 0.8,
#   'G': 0.9},
#  {'W': 0.1})

# %%
frame_id_range = [0, 40]
height_range = [10, 40]
diameter_range = [18, 25]
sm1_range = [3, 7]

# %%
def get_smooth1_data(surface_type):
    sm1 =  6.2

    if surface_type == 'S1': sm1 = 3.914
    elif surface_type == 'S2': sm1 = 7.5
    
    return (sm1 - sm1_range[0]) / (sm1_range[1] - sm1_range[0])

def get_delta_elevation(surface_type):
    delta_elevation = 0

    if surface_type == 'S4': delta_elevation = 0.33
    elif surface_type == 'S5': delta_elevation = 0.656
    elif surface_type == 'S6': delta_elevation = 1

    return delta_elevation

# %%
def analyze_conditions(path, frame_id):
    label = path.split('\\')[-1]
    seg = label.split('-')
    data = {}
    if len(seg) == 6:
        data['surface_type'] = surface_type_dict[seg[0]]
        data['liquid_type'] = liquid_type_dict[seg[1]]
        data['diameter'] = (int(seg[2][:2]) - diameter_range[0]) / (diameter_range[1] - diameter_range[0])
        data['height']  = (int(seg[3][:2]) - height_range[0]) / (height_range[1] - height_range[0])
        data['fall_point_type'] = fall_point_type_dict[seg[4]]
        data['frame_id'] = (frame_id - frame_id_range[0]) / (frame_id_range[1] - frame_id_range[0])
        data['sm1'] = get_smooth1_data(seg[0])
        data['sm2'] = 0.429
        data['delta_elevation'] = get_delta_elevation(seg[0])

    return data

# %%
def count_jpg_files(folder_path):
    jpg_files = [f for f in os.listdir(folder_path)
                 if f.endswith('.jpg')]
    return len(jpg_files)

# %%
def list_img_files(input_path):
	files = os.listdir(input_path)
	jpg_files = sorted([file for file in files if file.endswith('jpg')])
	jpg_files = sorted(jpg_files, key=lambda x: int(x.split('.')[-2][-3:]))
	return jpg_files

list_img_files(input_folder_path)
# Out:
# ['S1-W-18G-30cm-R-1_C001H001S0001000105.jpg',
#  'S1-W-18G-30cm-R-1_C001H001S0001000106.jpg',
#  'S1-W-18G-30cm-R-1_C001H001S0001000107.jpg',
#  'S1-W-18G-30cm-R-1_C001H001S0001000108.jpg',
#  'S1-W-18G-30cm-R-1_C001H001S0001000109.jpg',
#  'S1-W-18G-30cm-R-1_C001H001S0001000110.jpg',
#  'S1-W-18G-30cm-R-1_C001H001S0001000111.jpg',
#  'S1-W-18G-30cm-R-1_C001H001S0001000112.jpg',
#  'S1-W-18G-30cm-R-1_C001H001S0001000113.jpg',
#  'S1-W-18G-30cm-R-1_C001H001S0001000114.jpg',
#  'raw_S1-W-18G-30cm-R-1_C001H001S0001000115.jpg',
#  'raw_S1-W-18G-30cm-R-1_C001H001S0001000116.jpg',
#  'raw_S1-W-18G-30cm-R-1_C001H001S0001000117.jpg',
#  'raw_S1-W-18G-30cm-R-1_C001H001S0001000118.jpg',
#  'raw_S1-W-18G-30cm-R-1_C001H001S0001000119.jpg',
#  'raw_S1-W-18G-30cm-R-1_C001H001S0001000120.jpg',
#  'raw_S1-W-18G-30cm-R-1_C001H001S0001000121.jpg',
#  'raw_S1-W-18G-30cm-R-1_C001H001S0001000122.jpg',
#  'raw_S1-W-18G-30cm-R-1_C001H001S0001000123.jpg',
#  'raw_S1-W-18G-30cm-R-1_C001H001S0001000124.jpg',
#  'raw_S1-W-18G-30cm-R-1_C001H001S0001000125.jpg',
#  'raw_S1-W-18G-30cm-R-1_C001H001S0001000126.jpg',
#  'raw_S1-W-18G-30cm-R-1_C001H001S0001000127.jpg',
#  'raw_S1-W-18G-30cm-R-1_C001H001S0001000128.jpg',
#  'raw_S1-W-18G-30cm-R-1_C001H001S0001000129.jpg',
#  'raw_S1-W-18G-30cm-R-1_C001H001S0001000130.jpg',
#  'raw_S1-W-18G-30cm-R-1_C001H001S0001000131.jpg',
#  'raw_S1-W-18G-30cm-R-1_C001H001S0001000132.jpg',
#  'raw_S1-W-18G-30cm-R-1_C001H001S0001000133.jpg',
#  'raw_S1-W-18G-30cm-R-1_C001H001S0001000134.jpg']

# %%
def exec_one_folder(input_path, use_index_or_filename=True):
	img_files = list_img_files(input_path)
	logger.success(f'{input_path} listed, {len(img_files)} imgs found.')

	base_idx = count_jpg_files(output_feature_path)
	start_idx = 0
	cnt = 0
	for idx, path in enumerate(img_files):
		frame_id = int(path[-10:-4])
		if idx <= 1 : 
			start_idx = frame_id
			continue # skip the first several images
		output_img = cv2.imread(f'{input_path}/{img_files[idx]}')
		prev_output_img1 = cv2.imread(f'{input_path}/{img_files[idx-2]}')
		prev_output_img2 = cv2.imread(f'{input_path}/{img_files[idx-1]}')
	
		data = analyze_conditions(input_path, frame_id - start_idx)
		values = list(data.values())
		pts = [[i, i] for i in range(len(values))] 
		matrix = np.zeros((len(values), len(values)))
		for value, pt in zip(values, pts):
			matrix[pt[0], pt[1]] = value
		plt.imshow(matrix, cmap='viridis', interpolation='nearest')
		plt.axis('off')
		
		buf = BytesIO()
		plt.savefig(buf, format='jpg', bbox_inches='tight', pad_inches=0, dpi=300)
		plt.close()
		buf.seek(0)
		input_img = np.frombuffer(buf.getvalue(), dtype=np.int8)
		input_img = cv2.imdecode(input_img, cv2.IMREAD_COLOR)

		# prev_output_img1 = cv2.resize(prev_output_img1, (input_img.shape[1], int(input_img.shape[0]/2)))
		# prev_output_img2 = cv2.resize(prev_output_img2, (input_img.shape[1], int(input_img.shape[0]/2)))
		# prev_output_img = cv2.vconcat([prev_output_img1, prev_output_img2])
		# input_img = cv2.hconcat([input_img, prev_output_img])
		height, width = output_img.shape[:2]
		input_img = cv2.resize(input_img, (width, height))

		if use_index_or_filename:
			real_idx = base_idx + cnt
			cv2.imwrite(f'{output_feature_path}/{real_idx}.jpg', input_img)
			cv2.imwrite(f'{output_label_path}/{real_idx}.jpg', output_img)
			# with open(f'{output_data_path}/{real_idx}.json', 'w', encoding='utf-8') as fp:
			# 	json.dump(data, fp, ensure_ascii=False, indent=4)
		else:
			cv2.imwrite(f'{output_feature_path}/{img_files[idx]}.jpg', input_img)
			cv2.imwrite(f'{output_label_path}/{img_files[idx]}.jpg', output_img)
			# with open(f'{output_data_path}/{img_files[idx]}.json', 'w', encoding='utf-8') as fp:
			# 	json.dump(data, fp, ensure_ascii=False, indent=4)
		
		logger.success(f'Finish handling {input_path} / {idx}.')
		cnt += 1

# %%
exec_one_folder(input_path=input_folder_path, use_index_or_filename=False)
# Out:
# 2025-05-20 21:26:46.876 | SUCCESS  | __main__:exec_one_folder:3 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 listed, 30 imgs found.
# 2025-05-20 21:26:47.051 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 2.
# 2025-05-20 21:26:47.237 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 3.
# 2025-05-20 21:26:47.415 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 4.
# 2025-05-20 21:26:47.588 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 5.
# 2025-05-20 21:26:47.767 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 6.
# 2025-05-20 21:26:47.980 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 7.
# 2025-05-20 21:26:48.173 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 8.
# 2025-05-20 21:26:48.354 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 9.
# 2025-05-20 21:26:48.541 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 10.
# 2025-05-20 21:26:48.710 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 11.
# 2025-05-20 21:26:48.881 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 12.
# 2025-05-20 21:26:49.063 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 13.
# 2025-05-20 21:26:49.260 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 14.
# 2025-05-20 21:26:49.463 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 15.
# 2025-05-20 21:26:49.649 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 16.
# 2025-05-20 21:26:49.842 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 17.
# 2025-05-20 21:26:50.048 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 18.
# 2025-05-20 21:26:50.242 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 19.
# 2025-05-20 21:26:50.439 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 20.
# 2025-05-20 21:26:50.637 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 21.
# 2025-05-20 21:26:50.821 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 22.
# 2025-05-20 21:26:51.011 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 23.
# 2025-05-20 21:26:51.190 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 24.
# 2025-05-20 21:26:51.369 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 25.
# 2025-05-20 21:26:51.546 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 26.
# 2025-05-20 21:26:51.730 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 27.
# 2025-05-20 21:26:51.911 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 28.
# 2025-05-20 21:26:52.091 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 29.

# %%
for dataset_dir in dataset_dirs:
	input_path = os.path.join(input_folder_path, dataset_dir)
	exec_one_folder(input_path=input_path)
	logger.success(f"Finish handling {input_path}")
# Out:
# 2025-05-20 19:42:45.318 | SUCCESS  | __main__:exec_one_folder:3 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 listed, 30 imgs found.
# 2025-05-20 19:42:45.486 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 2.
# 2025-05-20 19:42:45.644 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 3.
# 2025-05-20 19:42:45.799 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 4.
# 2025-05-20 19:42:45.957 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 5.
# 2025-05-20 19:42:46.122 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 6.
# 2025-05-20 19:42:46.278 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 7.
# 2025-05-20 19:42:46.431 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 8.
# 2025-05-20 19:42:46.596 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 9.
# 2025-05-20 19:42:46.749 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 10.
# 2025-05-20 19:42:46.903 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 11.
# 2025-05-20 19:42:47.059 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 12.
# 2025-05-20 19:42:47.225 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 13.
# 2025-05-20 19:42:47.418 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 14.
# 2025-05-20 19:42:47.580 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 15.
# 2025-05-20 19:42:47.740 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 16.
# 2025-05-20 19:42:47.894 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 17.
# 2025-05-20 19:42:48.045 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 18.
# 2025-05-20 19:42:48.202 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 19.
# 2025-05-20 19:42:48.355 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 20.
# 2025-05-20 19:42:48.507 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 21.
# 2025-05-20 19:42:48.666 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 22.
# 2025-05-20 19:42:48.822 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 23.
# 2025-05-20 19:42:48.985 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 24.
# 2025-05-20 19:42:49.149 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 25.
# 2025-05-20 19:42:49.311 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 26.
# 2025-05-20 19:42:49.471 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 27.
# 2025-05-20 19:42:49.627 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 28.
# 2025-05-20 19:42:49.782 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001 / 29.
# 2025-05-20 19:42:49.784 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-C-1_C001H001S0001
# 2025-05-20 19:42:49.785 | SUCCESS  | __main__:exec_one_folder:3 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 listed, 30 imgs found.
# 2025-05-20 19:42:49.943 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 2.
# 2025-05-20 19:42:50.094 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 3.
# 2025-05-20 19:42:50.262 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 4.
# 2025-05-20 19:42:50.418 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 5.
# 2025-05-20 19:42:50.575 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 6.
# 2025-05-20 19:42:50.730 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 7.
# 2025-05-20 19:42:50.879 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 8.
# 2025-05-20 19:42:51.039 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 9.
# 2025-05-20 19:42:51.193 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 10.
# 2025-05-20 19:42:51.346 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 11.
# 2025-05-20 19:42:51.514 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 12.
# 2025-05-20 19:42:51.675 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 13.
# 2025-05-20 19:42:51.828 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 14.
# 2025-05-20 19:42:51.991 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 15.
# 2025-05-20 19:42:52.140 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 16.
# 2025-05-20 19:42:52.296 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 17.
# 2025-05-20 19:42:52.451 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 18.
# 2025-05-20 19:42:52.605 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 19.
# 2025-05-20 19:42:52.755 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 20.
# 2025-05-20 19:42:52.914 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 21.
# 2025-05-20 19:42:53.070 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 22.
# 2025-05-20 19:42:53.225 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 23.
# 2025-05-20 19:42:53.394 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 24.
# 2025-05-20 19:42:53.554 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 25.
# 2025-05-20 19:42:53.718 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 26.
# 2025-05-20 19:42:53.897 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 27.
# 2025-05-20 19:42:54.100 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 28.
# 2025-05-20 19:42:54.262 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001 / 29.
# 2025-05-20 19:42:54.263 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-30cm-R-1_C001H001S0001
# 2025-05-20 19:42:54.265 | SUCCESS  | __main__:exec_one_folder:3 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 listed, 30 imgs found.
# 2025-05-20 19:42:54.419 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 2.
# 2025-05-20 19:42:54.593 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 3.
# 2025-05-20 19:42:54.759 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 4.
# 2025-05-20 19:42:54.907 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 5.
# 2025-05-20 19:42:55.056 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 6.
# 2025-05-20 19:42:55.205 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 7.
# 2025-05-20 19:42:55.355 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 8.
# 2025-05-20 19:42:55.508 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 9.
# 2025-05-20 19:42:55.680 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 10.
# 2025-05-20 19:42:55.833 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 11.
# 2025-05-20 19:42:55.985 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 12.
# 2025-05-20 19:42:56.137 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 13.
# 2025-05-20 19:42:56.287 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 14.
# 2025-05-20 19:42:56.447 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 15.
# 2025-05-20 19:42:56.609 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 16.
# 2025-05-20 19:42:56.764 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 17.
# 2025-05-20 19:42:56.930 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 18.
# 2025-05-20 19:42:57.083 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 19.
# 2025-05-20 19:42:57.233 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 20.
# 2025-05-20 19:42:57.388 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 21.
# 2025-05-20 19:42:57.552 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 22.
# 2025-05-20 19:42:57.703 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 23.
# 2025-05-20 19:42:57.861 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 24.
# 2025-05-20 19:42:58.027 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 25.
# 2025-05-20 19:42:58.181 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 26.
# 2025-05-20 19:42:58.331 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 27.
# 2025-05-20 19:42:58.482 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 28.
# 2025-05-20 19:42:58.639 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001 / 29.
# 2025-05-20 19:42:58.640 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-C-1_C001H001S0001
# 2025-05-20 19:42:58.641 | SUCCESS  | __main__:exec_one_folder:3 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 listed, 30 imgs found.
# 2025-05-20 19:42:58.792 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 2.
# 2025-05-20 19:42:58.949 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 3.
# 2025-05-20 19:42:59.100 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 4.
# 2025-05-20 19:42:59.258 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 5.
# 2025-05-20 19:42:59.410 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 6.
# 2025-05-20 19:42:59.565 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 7.
# 2025-05-20 19:42:59.723 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 8.
# 2025-05-20 19:42:59.879 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 9.
# 2025-05-20 19:43:00.034 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 10.
# 2025-05-20 19:43:00.190 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 11.
# 2025-05-20 19:43:00.344 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 12.
# 2025-05-20 19:43:00.491 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 13.
# 2025-05-20 19:43:00.645 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 14.
# 2025-05-20 19:43:00.808 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 15.
# 2025-05-20 19:43:00.956 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 16.
# 2025-05-20 19:43:01.113 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 17.
# 2025-05-20 19:43:01.266 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 18.
# 2025-05-20 19:43:01.416 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 19.
# 2025-05-20 19:43:01.573 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 20.
# 2025-05-20 19:43:01.744 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 21.
# 2025-05-20 19:43:01.902 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 22.
# 2025-05-20 19:43:02.047 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 23.
# 2025-05-20 19:43:02.198 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 24.
# 2025-05-20 19:43:02.355 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 25.
# 2025-05-20 19:43:02.510 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 26.
# 2025-05-20 19:43:02.672 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 27.
# 2025-05-20 19:43:02.828 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 28.
# 2025-05-20 19:43:02.983 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001 / 29.
# 2025-05-20 19:43:02.985 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S1-W-18G-40cm-R-2_C001H001S0001
# 2025-05-20 19:43:02.986 | SUCCESS  | __main__:exec_one_folder:3 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 listed, 30 imgs found.
# 2025-05-20 19:43:03.148 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 2.
# 2025-05-20 19:43:03.314 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 3.
# 2025-05-20 19:43:03.462 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 4.
# 2025-05-20 19:43:03.615 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 5.
# 2025-05-20 19:43:03.771 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 6.
# 2025-05-20 19:43:03.920 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 7.
# 2025-05-20 19:43:04.075 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 8.
# 2025-05-20 19:43:04.232 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 9.
# 2025-05-20 19:43:04.381 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 10.
# 2025-05-20 19:43:04.538 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 11.
# 2025-05-20 19:43:04.687 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 12.
# 2025-05-20 19:43:04.843 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 13.
# 2025-05-20 19:43:04.993 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 14.
# 2025-05-20 19:43:05.147 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 15.
# 2025-05-20 19:43:05.304 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 16.
# 2025-05-20 19:43:05.459 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 17.
# 2025-05-20 19:43:05.611 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 18.
# 2025-05-20 19:43:05.761 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 19.
# 2025-05-20 19:43:05.912 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 20.
# 2025-05-20 19:43:06.074 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 21.
# 2025-05-20 19:43:06.229 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 22.
# 2025-05-20 19:43:06.381 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 23.
# 2025-05-20 19:43:06.547 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 24.
# 2025-05-20 19:43:06.697 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 25.
# 2025-05-20 19:43:06.847 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 26.
# 2025-05-20 19:43:06.996 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 27.
# 2025-05-20 19:43:07.156 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 28.
# 2025-05-20 19:43:07.318 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001 / 29.
# 2025-05-20 19:43:07.320 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-1_C001H001S0001
# 2025-05-20 19:43:07.322 | SUCCESS  | __main__:exec_one_folder:3 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 listed, 30 imgs found.
# 2025-05-20 19:43:07.475 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 2.
# 2025-05-20 19:43:07.633 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 3.
# 2025-05-20 19:43:07.797 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 4.
# 2025-05-20 19:43:07.964 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 5.
# 2025-05-20 19:43:08.125 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 6.
# 2025-05-20 19:43:08.291 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 7.
# 2025-05-20 19:43:08.457 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 8.
# 2025-05-20 19:43:08.626 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 9.
# 2025-05-20 19:43:08.796 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 10.
# 2025-05-20 19:43:08.972 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 11.
# 2025-05-20 19:43:09.152 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 12.
# 2025-05-20 19:43:09.313 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 13.
# 2025-05-20 19:43:09.479 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 14.
# 2025-05-20 19:43:09.663 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 15.
# 2025-05-20 19:43:09.836 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 16.
# 2025-05-20 19:43:10.015 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 17.
# 2025-05-20 19:43:10.213 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 18.
# 2025-05-20 19:43:10.388 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 19.
# 2025-05-20 19:43:11.137 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 20.
# 2025-05-20 19:43:11.285 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 21.
# 2025-05-20 19:43:11.431 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 22.
# 2025-05-20 19:43:11.582 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 23.
# 2025-05-20 19:43:11.756 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 24.
# 2025-05-20 19:43:11.912 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 25.
# 2025-05-20 19:43:12.073 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 26.
# 2025-05-20 19:43:12.215 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 27.
# 2025-05-20 19:43:12.365 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 28.
# 2025-05-20 19:43:12.516 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001 / 29.
# 2025-05-20 19:43:12.518 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-C-2_C001H001S0001
# 2025-05-20 19:43:12.519 | SUCCESS  | __main__:exec_one_folder:3 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 listed, 30 imgs found.
# 2025-05-20 19:43:12.662 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 2.
# 2025-05-20 19:43:12.814 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 3.
# 2025-05-20 19:43:12.961 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 4.
# 2025-05-20 19:43:13.109 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 5.
# 2025-05-20 19:43:13.257 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 6.
# 2025-05-20 19:43:13.411 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 7.
# 2025-05-20 19:43:13.575 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 8.
# 2025-05-20 19:43:13.728 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 9.
# 2025-05-20 19:43:13.881 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 10.
# 2025-05-20 19:43:14.028 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 11.
# 2025-05-20 19:43:14.180 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 12.
# 2025-05-20 19:43:14.332 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 13.
# 2025-05-20 19:43:14.479 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 14.
# 2025-05-20 19:43:14.649 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 15.
# 2025-05-20 19:43:14.807 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 16.
# 2025-05-20 19:43:14.954 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 17.
# 2025-05-20 19:43:15.104 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 18.
# 2025-05-20 19:43:15.264 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 19.
# 2025-05-20 19:43:15.413 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 20.
# 2025-05-20 19:43:15.560 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 21.
# 2025-05-20 19:43:15.706 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 22.
# 2025-05-20 19:43:15.860 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 23.
# 2025-05-20 19:43:16.011 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 24.
# 2025-05-20 19:43:16.157 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 25.
# 2025-05-20 19:43:16.314 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 26.
# 2025-05-20 19:43:16.457 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 27.
# 2025-05-20 19:43:16.604 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 28.
# 2025-05-20 19:43:16.746 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001 / 29.
# 2025-05-20 19:43:16.748 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-30cm-R-1_C001H001S0001
# 2025-05-20 19:43:16.750 | SUCCESS  | __main__:exec_one_folder:3 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-40cm-C-2_C001H001S0001 listed, 30 imgs found.
# 2025-05-20 19:43:16.897 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-40cm-C-2_C001H001S0001 / 2.
# 2025-05-20 19:43:17.052 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-40cm-C-2_C001H001S0001 / 3.
# 2025-05-20 19:43:17.196 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-40cm-C-2_C001H001S0001 / 4.
# 2025-05-20 19:43:17.347 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-40cm-C-2_C001H001S0001 / 5.
# 2025-05-20 19:43:17.496 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-40cm-C-2_C001H001S0001 / 6.
# 2025-05-20 19:43:17.657 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-40cm-C-2_C001H001S0001 / 7.
# 2025-05-20 19:43:17.807 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-40cm-C-2_C001H001S0001 / 8.
# 2025-05-20 19:43:17.960 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-40cm-C-2_C001H001S0001 / 9.
# 2025-05-20 19:43:18.112 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-40cm-C-2_C001H001S0001 / 10.
# 2025-05-20 19:43:18.253 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-40cm-C-2_C001H001S0001 / 11.
# 2025-05-20 19:43:18.399 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-40cm-C-2_C001H001S0001 / 12.
# 2025-05-20 19:43:18.550 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-40cm-C-2_C001H001S0001 / 13.
# 2025-05-20 19:43:18.707 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-40cm-C-2_C001H001S0001 / 14.
# 2025-05-20 19:43:18.852 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-40cm-C-2_C001H001S0001 / 15.
# 2025-05-20 19:43:19.001 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-40cm-C-2_C001H001S0001 / 16.
# 2025-05-20 19:43:19.145 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-40cm-C-2_C001H001S0001 / 17.
# 2025-05-20 19:43:19.288 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-40cm-C-2_C001H001S0001 / 18.
# 2025-05-20 19:43:19.530 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-40cm-C-2_C001H001S0001 / 19.
# 2025-05-20 19:43:19.680 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-40cm-C-2_C001H001S0001 / 20.
# 2025-05-20 19:43:19.831 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-40cm-C-2_C001H001S0001 / 21.
# 2025-05-20 19:43:19.978 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-40cm-C-2_C001H001S0001 / 22.
# 2025-05-20 19:43:20.122 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-40cm-C-2_C001H001S0001 / 23.
# 2025-05-20 19:43:20.268 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-40cm-C-2_C001H001S0001 / 24.
# 2025-05-20 19:43:20.414 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-40cm-C-2_C001H001S0001 / 25.
# 2025-05-20 19:43:20.565 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-40cm-C-2_C001H001S0001 / 26.
# 2025-05-20 19:43:20.712 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S2-W-18G-40cm-C-2_C001H001S0001 / 27.
# ...
# 2025-05-20 19:44:20.345 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-30cm-R-1_C001H001S0001 / 12.
# 2025-05-20 19:44:20.501 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-30cm-R-1_C001H001S0001 / 13.
# 2025-05-20 19:44:20.662 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-30cm-R-1_C001H001S0001 / 14.
# 2025-05-20 19:44:20.816 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-30cm-R-1_C001H001S0001 / 15.
# 2025-05-20 19:44:20.970 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-30cm-R-1_C001H001S0001 / 16.
# 2025-05-20 19:44:21.128 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-30cm-R-1_C001H001S0001 / 17.
# 2025-05-20 19:44:21.300 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-30cm-R-1_C001H001S0001 / 18.
# 2025-05-20 19:44:21.453 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-30cm-R-1_C001H001S0001 / 19.
# 2025-05-20 19:44:21.610 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-30cm-R-1_C001H001S0001 / 20.
# 2025-05-20 19:44:21.773 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-30cm-R-1_C001H001S0001 / 21.
# 2025-05-20 19:44:21.940 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-30cm-R-1_C001H001S0001 / 22.
# 2025-05-20 19:44:22.108 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-30cm-R-1_C001H001S0001 / 23.
# 2025-05-20 19:44:22.271 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-30cm-R-1_C001H001S0001 / 24.
# 2025-05-20 19:44:22.438 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-30cm-R-1_C001H001S0001 / 25.
# 2025-05-20 19:44:22.608 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-30cm-R-1_C001H001S0001 / 26.
# 2025-05-20 19:44:22.814 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-30cm-R-1_C001H001S0001 / 27.
# 2025-05-20 19:44:22.990 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-30cm-R-1_C001H001S0001 / 28.
# 2025-05-20 19:44:23.171 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-30cm-R-1_C001H001S0001 / 29.
# 2025-05-20 19:44:23.172 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-30cm-R-1_C001H001S0001
# 2025-05-20 19:44:23.173 | SUCCESS  | __main__:exec_one_folder:3 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 listed, 30 imgs found.
# 2025-05-20 19:44:23.340 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 2.
# 2025-05-20 19:44:23.516 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 3.
# 2025-05-20 19:44:23.683 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 4.
# 2025-05-20 19:44:23.855 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 5.
# 2025-05-20 19:44:24.027 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 6.
# 2025-05-20 19:44:24.207 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 7.
# 2025-05-20 19:44:24.379 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 8.
# 2025-05-20 19:44:24.567 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 9.
# 2025-05-20 19:44:24.820 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 10.
# 2025-05-20 19:44:25.015 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 11.
# 2025-05-20 19:44:25.178 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 12.
# 2025-05-20 19:44:25.336 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 13.
# 2025-05-20 19:44:25.494 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 14.
# 2025-05-20 19:44:25.803 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 15.
# 2025-05-20 19:44:25.995 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 16.
# 2025-05-20 19:44:26.150 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 17.
# 2025-05-20 19:44:26.314 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 18.
# 2025-05-20 19:44:26.463 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 19.
# 2025-05-20 19:44:26.617 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 20.
# 2025-05-20 19:44:26.764 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 21.
# 2025-05-20 19:44:26.929 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 22.
# 2025-05-20 19:44:27.091 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 23.
# 2025-05-20 19:44:27.236 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 24.
# 2025-05-20 19:44:27.392 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 25.
# 2025-05-20 19:44:27.540 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 26.
# 2025-05-20 19:44:27.692 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 27.
# 2025-05-20 19:44:27.843 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 28.
# 2025-05-20 19:44:27.991 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001 / 29.
# 2025-05-20 19:44:27.992 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-C-1_C001H001S0001
# 2025-05-20 19:44:27.994 | SUCCESS  | __main__:exec_one_folder:3 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 listed, 30 imgs found.
# 2025-05-20 19:44:28.162 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 2.
# 2025-05-20 19:44:28.314 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 3.
# 2025-05-20 19:44:28.467 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 4.
# 2025-05-20 19:44:28.613 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 5.
# 2025-05-20 19:44:28.761 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 6.
# 2025-05-20 19:44:28.912 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 7.
# 2025-05-20 19:44:29.066 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 8.
# 2025-05-20 19:44:29.226 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 9.
# 2025-05-20 19:44:29.379 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 10.
# 2025-05-20 19:44:29.525 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 11.
# 2025-05-20 19:44:29.670 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 12.
# 2025-05-20 19:44:29.820 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 13.
# 2025-05-20 19:44:29.969 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 14.
# 2025-05-20 19:44:30.121 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 15.
# 2025-05-20 19:44:30.273 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 16.
# 2025-05-20 19:44:30.429 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 17.
# 2025-05-20 19:44:30.577 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 18.
# 2025-05-20 19:44:30.726 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 19.
# 2025-05-20 19:44:30.875 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 20.
# 2025-05-20 19:44:31.036 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 21.
# 2025-05-20 19:44:31.185 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 22.
# 2025-05-20 19:44:31.335 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 23.
# 2025-05-20 19:44:31.492 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 24.
# 2025-05-20 19:44:31.650 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 25.
# 2025-05-20 19:44:31.800 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 26.
# 2025-05-20 19:44:31.952 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 27.
# 2025-05-20 19:44:32.099 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 28.
# 2025-05-20 19:44:32.255 | SUCCESS  | __main__:exec_one_folder:52 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001 / 29.
# 2025-05-20 19:44:32.257 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result2\S5-W-18G-40cm-R-1_C001H001S0001

# %%
# split train/valid/test
import os
import random
import shutil

# 定义源文件夹路径和目标文件夹路径
source_folder = './output/feature'
train_folder = './output/feature/train'
val_folder = './output/feature/valid'
test_folder = './output/feature/test'

# 创建目标文件夹（如果不存在）
os.makedirs(train_folder, exist_ok=True)
os.makedirs(val_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)

images = [f for f in os.listdir(source_folder) if os.path.isfile(os.path.join(source_folder, f))]

random.shuffle(images)

# 定义训练集，验证集，测试集比例
train_ratio = 0.0
val_ratio = 0.0

# 80% train + 10% valid + 10% test
train_size = int(train_ratio * len(images))
val_size = int(val_ratio * len(images))
test_size = len(images) - train_size - val_size

train_set = images[:train_size]
val_set = images[train_size:train_size + val_size]
test_set = images[train_size + val_size:]

def move_files(file_list, destination_folder):
    for file_name in file_list:
        src_path = os.path.join(source_folder, file_name)
        dst_path = os.path.join(destination_folder, file_name)
        shutil.move(src_path, dst_path)

move_files(train_set, train_folder)
move_files(val_set, val_folder)
move_files(test_set, test_folder)

print(f"train set: {len(train_set)} imgs")
print(f"valid set: {len(val_set)} imgs")
print(f"test set: {len(test_set)} imgs")
# Out:
# train set: 0 imgs
# valid set: 0 imgs
# test set: 28 imgs

# %%
# split train/valid/test
import os
import random
import shutil

# 定义源文件夹路径和目标文件夹路径
source_folder = './output/label'
train_folder = './output/label/train'
val_folder = './output/label/valid'
test_folder = './output/label/test'

# 创建目标文件夹（如果不存在）
os.makedirs(train_folder, exist_ok=True)
os.makedirs(val_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)

images = [f for f in os.listdir(source_folder) if os.path.isfile(os.path.join(source_folder, f))]

def move_files(file_list, destination_folder):
    for file_name in file_list:
        src_path = os.path.join(source_folder, file_name)
        dst_path = os.path.join(destination_folder, file_name)
        shutil.move(src_path, dst_path)

move_files(train_set, train_folder)
move_files(val_set, val_folder)
move_files(test_set, test_folder)

print(f"train set: {len(train_set)} imgs")
print(f"valid set: {len(val_set)} imgs")
print(f"test set: {len(test_set)} imgs")
# Out:
# train set: 0 imgs
# valid set: 0 imgs
# test set: 28 imgs
