# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
from io import BytesIO
from loguru import logger
import json

input_folder_path = r'E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001'
output_label_path = './output/label'
output_feature_path = './output/feature'
output_data_path = './output/data'

# %%
dataset_dirs = []


def list_directories(path):
    directories = [d for d in os.listdir(path)
                   if os.path.isdir(os.path.join(path, d))]
    return directories


dataset_dirs = list_directories(input_folder_path)
len(dataset_dirs)
# Out:
# 0

# %%
surface_type_keys = ['S1', 'S2', 'S3', 'S4', 'S5', 'S6']
surface_type_vals = [(i+1) / (len(surface_type_keys)+1) for i in range(len(surface_type_keys))]
surface_type_dict = dict(zip(surface_type_keys, surface_type_vals))

fall_point_type_keys = ['OG1', 'OG', 'OG2', 'OR1', 'OR', 'OR2', 'C', 'R', 'G']

fall_point_type_vals = [(i+1) / (len(fall_point_type_keys)+1) for i in range(len(fall_point_type_keys))]
fall_point_type_dict = dict(zip(fall_point_type_keys, fall_point_type_vals))

liquid_type_keys = ['W']
liquid_type_vals = [(i+1) / (len(fall_point_type_keys)+1)
                    for i in range(len(fall_point_type_keys))]
liquid_type_dict = dict(zip(liquid_type_keys, liquid_type_vals))

surface_type_dict, fall_point_type_dict, liquid_type_dict
# Out:
# ({'S1': 0.14285714285714285,
#   'S2': 0.2857142857142857,
#   'S3': 0.42857142857142855,
#   'S4': 0.5714285714285714,
#   'S5': 0.7142857142857143,
#   'S6': 0.8571428571428571},
#  {'OG1': 0.1,
#   'OG': 0.2,
#   'OG2': 0.3,
#   'OR1': 0.4,
#   'OR': 0.5,
#   'OR2': 0.6,
#   'C': 0.7,
#   'R': 0.8,
#   'G': 0.9},
#  {'W': 0.1})

# %%
frame_id_range = [0, 40]
height_range = [10, 40]
diameter_range = [18, 25]
sm1_range = [3, 7]

# %%
def get_smooth1_data(surface_type):
    sm1 =  6.2

    if surface_type == 'S1': sm1 = 3.914
    elif surface_type == 'S2': sm1 = 7.5
    
    return (sm1 - sm1_range[0]) / (sm1_range[1] - sm1_range[0])

def get_delta_elevation(surface_type):
    delta_elevation = 0

    if surface_type == 'S4': delta_elevation = 0.33
    elif surface_type == 'S5': delta_elevation = 0.656
    elif surface_type == 'S6': delta_elevation = 1

    return delta_elevation

# %%
def analyze_conditions(path, frame_id):
    label = path.split('\\')[-1]
    seg = label.split('-')
    data = {}
    if len(seg) == 6:
        data['surface_type'] = surface_type_dict[seg[0]]
        data['liquid_type'] = liquid_type_dict[seg[1]]
        data['diameter'] = (int(seg[2][:2]) - diameter_range[0]) / (diameter_range[1] - diameter_range[0])
        data['height']  = (int(seg[3][:2]) - height_range[0]) / (height_range[1] - height_range[0])
        data['fall_point_type'] = fall_point_type_dict[seg[4]]
        data['frame_id'] = (frame_id - frame_id_range[0]) / (frame_id_range[1] - frame_id_range[0])
        data['sm1'] = get_smooth1_data(seg[0])
        data['sm2'] = 0.429
        data['delta_elevation'] = get_delta_elevation(seg[0])

    return data

# %%
def count_jpg_files(folder_path):
    jpg_files = [f for f in os.listdir(folder_path)
                 if f.lower().endswith('.jpg')]
    return len(jpg_files)

# %%
def exec_one_folder(input_path, use_index_or_filename=True):
	def list_img_files():
		files = os.listdir(input_path)
		jpg_files = sorted([file for file in files if file.endswith('jpg') and file.startswith('raw')])
		return jpg_files
	img_files = list_img_files()
	logger.success(f'{input_path} listed, {len(img_files)} imgs found.')

	base_idx = count_jpg_files(output_feature_path)
	start_idx = 0
	cnt = 0
	for idx, path in enumerate(img_files):
		frame_id = int(path[-10:-4])
		if idx == 0 : start_idx = frame_id
		output_img = cv2.imread(f'{input_path}/{img_files[idx]}')
	
		data = analyze_conditions(input_path, frame_id - start_idx)
		values = list(data.values())
		pts = [[i, i] for i in range(len(values))] 
		matrix = np.zeros((len(values), len(values)))
		for value, pt in zip(values, pts):
			matrix[pt[0], pt[1]] = value
		plt.imshow(matrix, cmap='viridis', interpolation='nearest')
		plt.axis('off')
		
		buf = BytesIO()
		plt.savefig(buf, format='jpg', bbox_inches='tight', pad_inches=0, dpi=300)
		plt.close()
		buf.seek(0)
		input_img = np.frombuffer(buf.getvalue(), dtype=np.int8)
		input_img = cv2.imdecode(input_img, cv2.IMREAD_COLOR)
		height, width = output_img.shape[:2]
		input_img = cv2.resize(input_img, (width, height))

		if use_index_or_filename:
			real_idx = base_idx + cnt
			cv2.imwrite(f'{output_feature_path}/{real_idx}.jpg', input_img)
			cv2.imwrite(f'{output_label_path}/{real_idx}.jpg', output_img)
			with open(f'{output_data_path}/{real_idx}.json', 'w', encoding='utf-8') as fp:
				json.dump(data, fp, ensure_ascii=False, indent=4)
		else:
			cv2.imwrite(f'{output_feature_path}/{img_files[idx]}.jpg', input_img)
			cv2.imwrite(f'{output_label_path}/{img_files[idx]}.jpg', output_img)
			with open(f'{output_data_path}/{img_files[idx]}.json', 'w', encoding='utf-8') as fp:
				json.dump(data, fp, ensure_ascii=False, indent=4)
		
		logger.success(f'Finish handling {input_path} / {idx}.')
		cnt += 1

# %%
exec_one_folder(input_path=input_folder_path, use_index_or_filename=False)
# Out:
# 2025-05-05 22:00:59.702 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 listed, 22 imgs found.
# 2025-05-05 22:00:59.827 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 0.
# 2025-05-05 22:00:59.930 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 1.
# 2025-05-05 22:01:00.029 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 2.
# 2025-05-05 22:01:00.130 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 3.
# 2025-05-05 22:01:00.234 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 4.
# 2025-05-05 22:01:00.332 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 5.
# 2025-05-05 22:01:00.433 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 6.
# 2025-05-05 22:01:00.545 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 7.
# 2025-05-05 22:01:00.665 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 8.
# 2025-05-05 22:01:00.762 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 9.
# 2025-05-05 22:01:00.883 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 10.
# 2025-05-05 22:01:00.985 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 11.
# 2025-05-05 22:01:01.084 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 12.
# 2025-05-05 22:01:01.186 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 13.
# 2025-05-05 22:01:01.291 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 14.
# 2025-05-05 22:01:01.390 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 15.
# 2025-05-05 22:01:01.490 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 16.
# 2025-05-05 22:01:01.588 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 17.
# 2025-05-05 22:01:01.691 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 18.
# 2025-05-05 22:01:01.788 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 19.
# 2025-05-05 22:01:01.885 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 20.
# 2025-05-05 22:01:01.987 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 21.

# %%
for dataset_dir in dataset_dirs:
	input_path = os.path.join(input_folder_path, dataset_dir)
	exec_one_folder(input_path=input_path)
	logger.success(f"Finish handling {input_path}")
# Out:
# 2025-05-05 21:32:46.265 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 listed, 17 imgs found.
# 2025-05-05 21:32:46.648 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 0.
# 2025-05-05 21:32:46.778 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 1.
# 2025-05-05 21:32:46.900 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 2.
# 2025-05-05 21:32:47.021 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 3.
# 2025-05-05 21:32:47.141 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 4.
# 2025-05-05 21:32:47.267 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 5.
# 2025-05-05 21:32:47.398 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 6.
# 2025-05-05 21:32:47.531 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 7.
# 2025-05-05 21:32:47.675 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 8.
# 2025-05-05 21:32:47.815 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 9.
# 2025-05-05 21:32:47.949 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 10.
# 2025-05-05 21:32:48.071 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 11.
# 2025-05-05 21:32:48.204 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 12.
# 2025-05-05 21:32:48.377 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 13.
# 2025-05-05 21:32:48.511 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 14.
# 2025-05-05 21:32:48.643 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 15.
# 2025-05-05 21:32:48.780 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001 / 16.
# 2025-05-05 21:32:48.781 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-C-1_C001H001S0001
# 2025-05-05 21:32:48.782 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 listed, 22 imgs found.
# 2025-05-05 21:32:48.912 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 0.
# 2025-05-05 21:32:49.046 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 1.
# 2025-05-05 21:32:49.181 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 2.
# 2025-05-05 21:32:49.308 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 3.
# 2025-05-05 21:32:49.433 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 4.
# 2025-05-05 21:32:49.573 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 5.
# 2025-05-05 21:32:49.717 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 6.
# 2025-05-05 21:32:49.845 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 7.
# 2025-05-05 21:32:49.977 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 8.
# 2025-05-05 21:32:50.111 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 9.
# 2025-05-05 21:32:50.254 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 10.
# 2025-05-05 21:32:50.377 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 11.
# 2025-05-05 21:32:50.495 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 12.
# 2025-05-05 21:32:50.615 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 13.
# 2025-05-05 21:32:50.733 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 14.
# 2025-05-05 21:32:50.859 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 15.
# 2025-05-05 21:32:50.991 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 16.
# 2025-05-05 21:32:51.117 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 17.
# 2025-05-05 21:32:51.244 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 18.
# 2025-05-05 21:32:51.372 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 19.
# 2025-05-05 21:32:51.503 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 20.
# 2025-05-05 21:32:51.633 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001 / 21.
# 2025-05-05 21:32:51.634 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-30cm-R-1_C001H001S0001
# 2025-05-05 21:32:51.634 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 listed, 24 imgs found.
# 2025-05-05 21:32:51.753 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 0.
# 2025-05-05 21:32:51.883 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 1.
# 2025-05-05 21:32:52.004 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 2.
# 2025-05-05 21:32:52.138 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 3.
# 2025-05-05 21:32:52.268 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 4.
# 2025-05-05 21:32:52.409 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 5.
# 2025-05-05 21:32:52.543 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 6.
# 2025-05-05 21:32:52.686 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 7.
# 2025-05-05 21:32:52.828 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 8.
# 2025-05-05 21:32:52.956 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 9.
# 2025-05-05 21:32:53.091 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 10.
# 2025-05-05 21:32:53.223 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 11.
# 2025-05-05 21:32:53.417 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 12.
# 2025-05-05 21:32:53.547 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 13.
# 2025-05-05 21:32:53.683 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 14.
# 2025-05-05 21:32:53.817 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 15.
# 2025-05-05 21:32:53.954 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 16.
# 2025-05-05 21:32:54.084 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 17.
# 2025-05-05 21:32:54.212 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 18.
# 2025-05-05 21:32:54.346 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 19.
# 2025-05-05 21:32:54.484 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 20.
# 2025-05-05 21:32:54.601 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 21.
# 2025-05-05 21:32:54.718 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 22.
# 2025-05-05 21:32:54.824 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001 / 23.
# 2025-05-05 21:32:54.825 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-C-1_C001H001S0001
# 2025-05-05 21:32:54.826 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 listed, 24 imgs found.
# 2025-05-05 21:32:54.935 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 0.
# 2025-05-05 21:32:55.056 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 1.
# 2025-05-05 21:32:55.181 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 2.
# 2025-05-05 21:32:55.303 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 3.
# 2025-05-05 21:32:55.419 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 4.
# 2025-05-05 21:32:55.531 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 5.
# 2025-05-05 21:32:55.645 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 6.
# 2025-05-05 21:32:55.748 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 7.
# 2025-05-05 21:32:55.854 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 8.
# 2025-05-05 21:32:55.959 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 9.
# 2025-05-05 21:32:56.063 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 10.
# 2025-05-05 21:32:56.182 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 11.
# 2025-05-05 21:32:56.296 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 12.
# 2025-05-05 21:32:56.426 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 13.
# 2025-05-05 21:32:56.527 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 14.
# 2025-05-05 21:32:56.634 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 15.
# 2025-05-05 21:32:56.755 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 16.
# 2025-05-05 21:32:56.856 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 17.
# 2025-05-05 21:32:56.958 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 18.
# 2025-05-05 21:32:57.062 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 19.
# 2025-05-05 21:32:57.160 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 20.
# 2025-05-05 21:32:57.261 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 21.
# 2025-05-05 21:32:57.367 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 22.
# 2025-05-05 21:32:57.467 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001 / 23.
# 2025-05-05 21:32:57.467 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S1-W-18G-40cm-R-2_C001H001S0001
# 2025-05-05 21:32:57.468 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 listed, 21 imgs found.
# 2025-05-05 21:32:57.584 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 0.
# 2025-05-05 21:32:57.695 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 1.
# 2025-05-05 21:32:57.853 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 2.
# 2025-05-05 21:32:57.953 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 3.
# 2025-05-05 21:32:58.056 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 4.
# 2025-05-05 21:32:58.183 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 5.
# 2025-05-05 21:32:58.313 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 6.
# 2025-05-05 21:32:58.432 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 7.
# 2025-05-05 21:32:58.550 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 8.
# 2025-05-05 21:32:58.676 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 9.
# 2025-05-05 21:32:58.802 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 10.
# 2025-05-05 21:32:58.925 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 11.
# 2025-05-05 21:32:59.056 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 12.
# 2025-05-05 21:32:59.185 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 13.
# 2025-05-05 21:32:59.297 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 14.
# 2025-05-05 21:32:59.421 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 15.
# 2025-05-05 21:32:59.545 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 16.
# 2025-05-05 21:32:59.663 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 17.
# 2025-05-05 21:32:59.783 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 18.
# 2025-05-05 21:32:59.904 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 19.
# 2025-05-05 21:33:00.024 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001 / 20.
# 2025-05-05 21:33:00.025 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-1_C001H001S0001
# 2025-05-05 21:33:00.026 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 listed, 28 imgs found.
# 2025-05-05 21:33:00.155 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 0.
# 2025-05-05 21:33:00.303 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 1.
# 2025-05-05 21:33:00.444 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 2.
# 2025-05-05 21:33:00.565 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 3.
# 2025-05-05 21:33:00.690 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 4.
# 2025-05-05 21:33:00.822 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 5.
# 2025-05-05 21:33:00.951 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 6.
# 2025-05-05 21:33:01.076 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 7.
# 2025-05-05 21:33:01.214 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 8.
# 2025-05-05 21:33:01.349 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 9.
# 2025-05-05 21:33:01.471 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 10.
# 2025-05-05 21:33:01.603 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 11.
# 2025-05-05 21:33:01.731 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 12.
# 2025-05-05 21:33:01.853 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 13.
# 2025-05-05 21:33:01.988 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 14.
# 2025-05-05 21:33:02.118 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 15.
# 2025-05-05 21:33:02.240 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 16.
# 2025-05-05 21:33:02.365 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 17.
# 2025-05-05 21:33:02.501 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 18.
# 2025-05-05 21:33:02.638 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 19.
# 2025-05-05 21:33:02.765 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 20.
# 2025-05-05 21:33:02.888 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 21.
# 2025-05-05 21:33:03.014 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 22.
# 2025-05-05 21:33:03.137 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 23.
# 2025-05-05 21:33:03.273 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 24.
# 2025-05-05 21:33:03.398 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 25.
# 2025-05-05 21:33:03.592 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 26.
# 2025-05-05 21:33:03.716 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001 / 27.
# 2025-05-05 21:33:03.716 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-C-2_C001H001S0001
# 2025-05-05 21:33:03.719 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 listed, 35 imgs found.
# 2025-05-05 21:33:03.842 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 0.
# 2025-05-05 21:33:03.972 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 1.
# 2025-05-05 21:33:04.095 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 2.
# 2025-05-05 21:33:04.219 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 3.
# 2025-05-05 21:33:04.344 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 4.
# 2025-05-05 21:33:04.479 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 5.
# 2025-05-05 21:33:04.604 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 6.
# 2025-05-05 21:33:04.727 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 7.
# 2025-05-05 21:33:04.850 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 8.
# 2025-05-05 21:33:04.980 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 9.
# 2025-05-05 21:33:05.116 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 10.
# 2025-05-05 21:33:05.248 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 11.
# 2025-05-05 21:33:05.373 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 12.
# 2025-05-05 21:33:05.500 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 13.
# 2025-05-05 21:33:05.625 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 14.
# 2025-05-05 21:33:05.760 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 15.
# 2025-05-05 21:33:05.888 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 16.
# 2025-05-05 21:33:06.016 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 17.
# 2025-05-05 21:33:06.144 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 18.
# 2025-05-05 21:33:06.270 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 19.
# 2025-05-05 21:33:06.404 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 20.
# 2025-05-05 21:33:06.533 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 21.
# 2025-05-05 21:33:06.661 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 22.
# 2025-05-05 21:33:06.783 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 23.
# 2025-05-05 21:33:06.913 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 24.
# 2025-05-05 21:33:07.041 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 25.
# 2025-05-05 21:33:07.165 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 26.
# 2025-05-05 21:33:07.293 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 27.
# 2025-05-05 21:33:07.414 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 28.
# 2025-05-05 21:33:07.540 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 29.
# 2025-05-05 21:33:07.671 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 30.
# 2025-05-05 21:33:07.804 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 31.
# 2025-05-05 21:33:07.933 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 32.
# 2025-05-05 21:33:08.061 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 33.
# 2025-05-05 21:33:08.188 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001 / 34.
# 2025-05-05 21:33:08.189 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-30cm-R-1_C001H001S0001
# 2025-05-05 21:33:08.190 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 listed, 21 imgs found.
# 2025-05-05 21:33:08.321 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 0.
# 2025-05-05 21:33:08.452 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 1.
# 2025-05-05 21:33:08.577 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 2.
# 2025-05-05 21:33:08.704 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 3.
# 2025-05-05 21:33:08.831 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 4.
# 2025-05-05 21:33:08.963 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 5.
# 2025-05-05 21:33:09.091 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 6.
# 2025-05-05 21:33:09.216 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 7.
# 2025-05-05 21:33:09.342 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 8.
# 2025-05-05 21:33:09.468 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 9.
# 2025-05-05 21:33:09.599 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 10.
# 2025-05-05 21:33:09.728 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 11.
# 2025-05-05 21:33:09.851 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 12.
# 2025-05-05 21:33:09.975 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 13.
# 2025-05-05 21:33:10.094 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 14.
# 2025-05-05 21:33:10.224 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 15.
# 2025-05-05 21:33:10.348 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 16.
# 2025-05-05 21:33:10.472 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 17.
# 2025-05-05 21:33:10.675 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 18.
# 2025-05-05 21:33:10.809 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 19.
# 2025-05-05 21:33:10.945 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001 / 20.
# 2025-05-05 21:33:10.946 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-C-2_C001H001S0001
# 2025-05-05 21:33:10.947 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 listed, 21 imgs found.
# 2025-05-05 21:33:11.079 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 0.
# 2025-05-05 21:33:11.204 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 1.
# 2025-05-05 21:33:11.335 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 2.
# 2025-05-05 21:33:11.481 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 3.
# 2025-05-05 21:33:11.614 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 4.
# 2025-05-05 21:33:11.748 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 5.
# 2025-05-05 21:33:11.883 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 6.
# 2025-05-05 21:33:12.014 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 7.
# 2025-05-05 21:33:12.153 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 8.
# 2025-05-05 21:33:12.281 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 9.
# 2025-05-05 21:33:12.408 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 10.
# 2025-05-05 21:33:12.544 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 11.
# 2025-05-05 21:33:12.690 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 12.
# 2025-05-05 21:33:12.823 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 13.
# 2025-05-05 21:33:12.953 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 14.
# 2025-05-05 21:33:13.083 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 15.
# 2025-05-05 21:33:13.213 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 16.
# 2025-05-05 21:33:13.347 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 17.
# 2025-05-05 21:33:13.481 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 18.
# 2025-05-05 21:33:13.610 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 19.
# 2025-05-05 21:33:13.758 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001 / 20.
# 2025-05-05 21:33:13.760 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-1_C001H001S0001
# 2025-05-05 21:33:13.760 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-2_C001H001S0001 listed, 18 imgs found.
# 2025-05-05 21:33:13.900 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-2_C001H001S0001 / 0.
# 2025-05-05 21:33:14.031 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-2_C001H001S0001 / 1.
# 2025-05-05 21:33:14.152 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-2_C001H001S0001 / 2.
# 2025-05-05 21:33:14.291 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-2_C001H001S0001 / 3.
# 2025-05-05 21:33:14.420 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-2_C001H001S0001 / 4.
# 2025-05-05 21:33:14.551 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S2-W-18G-40cm-R-2_C001H001S0001 / 5.
# ...
# 2025-05-05 21:34:01.745 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-1_C001H001S0001 / 12.
# 2025-05-05 21:34:01.858 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-1_C001H001S0001 / 13.
# 2025-05-05 21:34:01.966 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-1_C001H001S0001 / 14.
# 2025-05-05 21:34:02.079 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-1_C001H001S0001 / 15.
# 2025-05-05 21:34:02.190 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-1_C001H001S0001 / 16.
# 2025-05-05 21:34:02.303 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-1_C001H001S0001 / 17.
# 2025-05-05 21:34:02.415 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-1_C001H001S0001 / 18.
# 2025-05-05 21:34:02.531 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-1_C001H001S0001 / 19.
# 2025-05-05 21:34:02.649 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-1_C001H001S0001 / 20.
# 2025-05-05 21:34:02.650 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-1_C001H001S0001
# 2025-05-05 21:34:02.652 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 listed, 21 imgs found.
# 2025-05-05 21:34:02.768 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 0.
# 2025-05-05 21:34:02.890 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 1.
# 2025-05-05 21:34:03.018 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 2.
# 2025-05-05 21:34:03.138 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 3.
# 2025-05-05 21:34:03.251 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 4.
# 2025-05-05 21:34:03.367 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 5.
# 2025-05-05 21:34:03.479 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 6.
# 2025-05-05 21:34:03.598 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 7.
# 2025-05-05 21:34:03.720 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 8.
# 2025-05-05 21:34:03.843 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 9.
# 2025-05-05 21:34:03.963 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 10.
# 2025-05-05 21:34:04.082 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 11.
# 2025-05-05 21:34:04.207 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 12.
# 2025-05-05 21:34:04.329 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 13.
# 2025-05-05 21:34:04.454 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 14.
# 2025-05-05 21:34:04.580 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 15.
# 2025-05-05 21:34:04.697 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 16.
# 2025-05-05 21:34:04.819 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 17.
# 2025-05-05 21:34:04.940 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 18.
# 2025-05-05 21:34:05.065 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 19.
# 2025-05-05 21:34:05.200 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001 / 20.
# 2025-05-05 21:34:05.201 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-C-2_C001H001S0001
# 2025-05-05 21:34:05.205 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 listed, 21 imgs found.
# 2025-05-05 21:34:05.342 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 0.
# 2025-05-05 21:34:05.463 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 1.
# 2025-05-05 21:34:05.585 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 2.
# 2025-05-05 21:34:05.707 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 3.
# 2025-05-05 21:34:05.833 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 4.
# 2025-05-05 21:34:05.962 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 5.
# 2025-05-05 21:34:06.084 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 6.
# 2025-05-05 21:34:06.205 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 7.
# 2025-05-05 21:34:06.328 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 8.
# 2025-05-05 21:34:06.459 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 9.
# 2025-05-05 21:34:06.586 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 10.
# 2025-05-05 21:34:06.709 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 11.
# 2025-05-05 21:34:06.834 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 12.
# 2025-05-05 21:34:06.956 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 13.
# 2025-05-05 21:34:07.077 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 14.
# 2025-05-05 21:34:07.202 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 15.
# 2025-05-05 21:34:07.324 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 16.
# 2025-05-05 21:34:07.445 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 17.
# 2025-05-05 21:34:07.568 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 18.
# 2025-05-05 21:34:07.692 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 19.
# 2025-05-05 21:34:07.817 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001 / 20.
# 2025-05-05 21:34:07.818 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-G-1_C001H001S0001
# 2025-05-05 21:34:07.819 | SUCCESS  | __main__:exec_one_folder:7 - E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 listed, 21 imgs found.
# 2025-05-05 21:34:07.943 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 0.
# 2025-05-05 21:34:08.065 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 1.
# 2025-05-05 21:34:08.188 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 2.
# 2025-05-05 21:34:08.319 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 3.
# 2025-05-05 21:34:08.443 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 4.
# 2025-05-05 21:34:08.573 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 5.
# 2025-05-05 21:34:08.704 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 6.
# 2025-05-05 21:34:08.828 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 7.
# 2025-05-05 21:34:08.953 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 8.
# 2025-05-05 21:34:09.084 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 9.
# 2025-05-05 21:34:09.205 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 10.
# 2025-05-05 21:34:09.329 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 11.
# 2025-05-05 21:34:09.455 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 12.
# 2025-05-05 21:34:09.586 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 13.
# 2025-05-05 21:34:09.708 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 14.
# 2025-05-05 21:34:09.833 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 15.
# 2025-05-05 21:34:09.960 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 16.
# 2025-05-05 21:34:10.082 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 17.
# 2025-05-05 21:34:10.208 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 18.
# 2025-05-05 21:34:10.340 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 19.
# 2025-05-05 21:34:10.463 | SUCCESS  | __main__:exec_one_folder:47 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001 / 20.
# 2025-05-05 21:34:10.464 | SUCCESS  | __main__:<module>:4 - Finish handling E:\record\Drop Impact on Rough Surfaces_1\Drop Impact on Rough Surfaces_1\result\S6-W-18G-40cm-R-1_C001H001S0001

# %%
# split train/valid/test
import os
import random
import shutil

# 定义源文件夹路径和目标文件夹路径
source_folder = './output/feature'
train_folder = './output/feature/train'
val_folder = './output/feature/valid'
test_folder = './output/feature/test'

# 创建目标文件夹（如果不存在）
os.makedirs(train_folder, exist_ok=True)
os.makedirs(val_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)

images = [f for f in os.listdir(source_folder) if os.path.isfile(os.path.join(source_folder, f))]

random.shuffle(images)

# 定义训练集，验证集，测试集比例
train_ratio = 0.0
val_ratio = 0.0

# 80% train + 10% valid + 10% test
train_size = int(train_ratio * len(images))
val_size = int(val_ratio * len(images))
test_size = len(images) - train_size - val_size

train_set = images[:train_size]
val_set = images[train_size:train_size + val_size]
test_set = images[train_size + val_size:]

def move_files(file_list, destination_folder):
    for file_name in file_list:
        src_path = os.path.join(source_folder, file_name)
        dst_path = os.path.join(destination_folder, file_name)
        shutil.move(src_path, dst_path)

move_files(train_set, train_folder)
move_files(val_set, val_folder)
move_files(test_set, test_folder)

print(f"train set: {len(train_set)} imgs")
print(f"valid set: {len(val_set)} imgs")
print(f"test set: {len(test_set)} imgs")
# Out:
# train set: 0 imgs
# valid set: 0 imgs
# test set: 22 imgs

# %%
# split train/valid/test
import os
import random
import shutil

# 定义源文件夹路径和目标文件夹路径
source_folder = './output/label'
train_folder = './output/label/train'
val_folder = './output/label/valid'
test_folder = './output/label/test'

# 创建目标文件夹（如果不存在）
os.makedirs(train_folder, exist_ok=True)
os.makedirs(val_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)

images = [f for f in os.listdir(source_folder) if os.path.isfile(os.path.join(source_folder, f))]

def move_files(file_list, destination_folder):
    for file_name in file_list:
        src_path = os.path.join(source_folder, file_name)
        dst_path = os.path.join(destination_folder, file_name)
        shutil.move(src_path, dst_path)

move_files(train_set, train_folder)
move_files(val_set, val_folder)
move_files(test_set, test_folder)

print(f"train set: {len(train_set)} imgs")
print(f"valid set: {len(val_set)} imgs")
print(f"test set: {len(test_set)} imgs")
# Out:
# train set: 0 imgs
# valid set: 0 imgs
# test set: 22 imgs
